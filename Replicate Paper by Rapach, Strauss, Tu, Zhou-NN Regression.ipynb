# %% [markdown]
# Replicate [Dynamic Return Dependencies Across Industries: A Machine Learning Approach](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=3120110&download=yes) by David Rapach, Jack Strauss, Jun Tu and Guofu Zhou.
#
# 1) Use Keras NNs instead of linear regression
#
# 2) Add additional variables, 3 and 12-month MA, interest rate change, yield curve, Mkt-RF. The hope is with  cross-validation and regularization we can do that without overfitting.

# %%
import os
import sys
import warnings
import numpy as np
import pandas as pd
import pandas_datareader.data as datareader
import time 
import datetime
import copy
import random
from itertools import product

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' #Hide messy TensorFlow warnings
warnings.filterwarnings("ignore") #Hide messy numpy warnings

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, explained_variance_score, r2_score
from sklearn.linear_model import LinearRegression, Lasso, lasso_path, lars_path, LassoLarsIC
from sklearn.ensemble.forest import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import MinMaxScaler, StandardScaler


import tensorflow as tf
tf.set_random_seed(1764)

import keras
from keras.layers.core import Dense, Activation, Dropout
from keras.layers import Input
from keras.models import Model

from keras.layers.recurrent import LSTM, GRU
from keras.regularizers import l1
from keras.models import Sequential
from keras.models import load_model

import ffn
# %matplotlib inline

import plotly as py
# print (py.__version__) # requires version >= 1.9.0
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
import plotly.figure_factory as ff

init_notebook_mode(connected=True)

random.seed(1764)
np.random.seed(1764)
# Out:
# Using TensorFlow backend.
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
print("Loading data...")
data = pd.read_csv("30_Industry_Portfolios.csv")
data = data.set_index('yyyymm')
industries = list(data.columns)
# map industry names to col nums
ind_reverse_dict = dict([(industries[i], i) for i in range(len(industries))])

rfdata = pd.read_csv("F-F_Research_Data_Factors.csv")
rfdata = rfdata.set_index('yyyymm')
data['rf'] = rfdata['RF']

# subtract risk-free rate
# create a response variable led by 1 period to predict
for ind in industries:
    data[ind] = data[ind] - data['rf']

    
# add rates data from FRED
start_date = datetime.datetime(1926, 9, 1)
end_date = datetime.datetime(2017, 12, 1)
TB3MS = datareader.DataReader("TB3MS", "fred", start_date, end_date)
TB3MS['yyyymm'] = TB3MS.index.strftime('%Y%m')
TB3MS['yyyymm'] = [int(datestr) for datestr in TB3MS['yyyymm']]
TB3MS=TB3MS.set_index(['yyyymm'])
data['3month']=TB3MS['TB3MS']

GS10 =  datareader.DataReader("GS10", "fred", start_date, end_date)
GS10['yyyymm'] = GS10.index.strftime('%Y%m')
GS10['yyyymm'] = [int(datestr) for datestr in GS10['yyyymm']]
GS10=GS10.set_index(['yyyymm'])
data['10year']=GS10['GS10']

data['curve'] = data['10year'] - data['3month']
data['10year'] = data['10year'].diff() # first difference 10-year yield
data['3month'] = data['3month'].diff() # first difference 3-month
data['month'] = (data.index  % 100)/12.0 # for possible seasonality
data['Mkt-RF'] = rfdata['Mkt-RF']

for ind in industries + ['3month', '10year', 'curve', 'Mkt-RF',]:
    data[ind+".3m"] = pd.rolling_mean(data[ind],3)
    
#for ind in industries + ['3month', '10year', 'curve', 'Mkt-RF',]:
#    data[ind+".6m"] = pd.rolling_mean(data[ind],6)

for ind in industries + ['3month', '10year', 'curve', 'Mkt-RF',]:
    data[ind+".12m"] = pd.rolling_mean(data[ind],12)

for ind in industries:
    data[ind+".lead"] = data[ind].shift(-1)

data = data.loc[data.index[data.index > 195911]]
data = data.drop(columns=['rf'])    
data = data.dropna(axis=0, how='any')

nresponses = len(industries)
npredictors = data.shape[1]-nresponses

predictors = list(data.columns[:npredictors])
predictor_reverse_dict = dict([(predictors[i], i) for i in range(len(predictors))])

responses = list(data.columns[-nresponses:])
response_reverse_dict = dict([(responses[i], i) for i in range(len(responses))])

print(data.shape)
print(list(data.columns))
data[['3month', '10year', 'curve', 'month', 'Mkt-RF',]]
# Out:
# Loading data...
# (697, 133)
# ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m', 'Food.lead', 'Beer.lead', 'Smoke.lead', 'Games.lead', 'Books.lead', 'Hshld.lead', 'Clths.lead', 'Hlth.lead', 'Chems.lead', 'Txtls.lead', 'Cnstr.lead', 'Steel.lead', 'FabPr.lead', 'ElcEq.lead', 'Autos.lead', 'Carry.lead', 'Mines.lead', 'Coal.lead', 'Oil.lead', 'Util.lead', 'Telcm.lead', 'Servs.lead', 'BusEq.lead', 'Paper.lead', 'Trans.lead', 'Whlsl.lead', 'Rtail.lead', 'Meals.lead', 'Fin.lead', 'Other.lead']
#         3month  10year  curve     month  Mkt-RF
# yyyymm
# 195912    0.34    0.16   0.20  1.000000    2.45
# 196001   -0.14    0.03   0.37  0.083333   -6.98
# 196002   -0.39   -0.23   0.53  0.166667    1.17
# 196003   -0.65   -0.24   0.94  0.250000   -1.63
# 196004   -0.08    0.03   1.05  0.333333   -1.71
# 196005    0.06    0.07   1.06  0.416667    3.12
# 196006   -0.83   -0.20   1.69  0.500000    2.08
# 196007   -0.16   -0.25   1.60  0.583333   -2.37
# 196008    0.00   -0.10   1.50  0.666667    3.01
# 196009    0.18    0.00   1.32  0.750000   -5.99
# 196010   -0.18    0.09   1.59  0.833333   -0.71
# 196011    0.07    0.04   1.56  0.916667    4.69
# 196012   -0.12   -0.09   1.59  1.000000    4.71
# 196101   -0.01    0.00   1.60  0.083333    6.20
# 196102    0.18   -0.06   1.36  0.166667    3.57
# 196103   -0.03   -0.04   1.35  0.250000    2.89
# 196104   -0.10    0.04   1.49  0.333333    0.29
# 196105    0.00   -0.07   1.42  0.416667    2.40
# 196106    0.04    0.17   1.55  0.500000   -3.08
# 196107   -0.09    0.04   1.68  0.583333    2.83
# 196108    0.15    0.12   1.65  0.666667    2.57
# 196109   -0.11   -0.06   1.70  0.750000   -2.15
# 196110    0.02   -0.06   1.62  0.833333    2.57
# 196111    0.18    0.02   1.46  0.916667    4.45
# 196112    0.12    0.12   1.46  1.000000   -0.18
# 196201    0.12    0.02   1.36  0.083333   -3.87
# 196202    0.01   -0.04   1.31  0.166667    1.81
# 196203   -0.01   -0.11   1.21  0.250000   -0.68
# 196204    0.01   -0.09   1.11  0.333333   -6.59
# 196205   -0.04    0.03   1.18  0.416667   -8.65
# ...        ...     ...    ...       ...     ...
# 201507    0.01   -0.04   2.29  0.583333    1.54
# 201508    0.04   -0.15   2.10  0.666667   -6.04
# 201509   -0.05    0.00   2.15  0.750000   -3.08
# 201510    0.00   -0.10   2.05  0.833333    7.75
# 201511    0.10    0.19   2.14  0.916667    0.56
# 201512    0.11   -0.02   2.01  1.000000   -2.17
# 201601    0.03   -0.15   1.83  0.083333   -5.77
# 201602    0.05   -0.31   1.47  0.166667   -0.07
# 201603   -0.02    0.11   1.60  0.250000    6.96
# 201604   -0.06   -0.08   1.58  0.333333    0.92
# 201605    0.04    0.00   1.54  0.416667    1.78
# 201606    0.00   -0.17   1.37  0.500000   -0.05
# 201607    0.03   -0.14   1.20  0.583333    3.95
# 201608    0.00    0.06   1.26  0.666667    0.50
# 201609   -0.01    0.07   1.34  0.750000    0.25
# 201610    0.04    0.13   1.43  0.833333   -2.02
# 201611    0.12    0.38   1.69  0.916667    4.86
# 201612    0.06    0.35   1.98  1.000000    1.82
# 201701    0.00   -0.06   1.92  0.083333    1.94
# 201702    0.01   -0.01   1.90  0.166667    3.57
# 201703    0.22    0.06   1.74  0.250000    0.17
# 201704    0.06   -0.18   1.50  0.333333    1.09
# 201705    0.09    0.00   1.41  0.416667    1.06
# 201706    0.09   -0.11   1.21  0.500000    0.78
# 201707    0.09    0.13   1.25  0.583333    1.87
# 201708   -0.06   -0.11   1.20  0.666667    0.16
# 201709    0.02   -0.01   1.17  0.750000    2.51
# 201710    0.04    0.16   1.29  0.833333    2.25
# 201711    0.16   -0.01   1.12  0.916667    3.12
# 201712    0.09    0.05   1.08  1.000000    1.06
#
# [697 rows x 5 columns]

# %%
#data = data.loc[data.index[data.index < 201701]]
data = data.loc[data.index[data.index > 195911]]
data
# Out:
#          Food  Beer  Smoke  Games  Books  Hshld  Clths   Hlth  Chems  Txtls  \
# yyyymm
# 195912   2.01  0.35  -3.02   1.64   7.29   0.67   1.87  -1.97   3.08   0.74
# 196001  -4.49 -5.71  -2.05   1.21  -5.47  -7.84  -8.53  -6.68 -10.03  -4.77
# 196002   3.35 -2.14   2.27   4.23   2.39   9.31   1.44  -0.02  -0.74   0.32
# 196003  -1.67 -2.94  -0.18  -0.65   2.18  -0.56  -2.59   1.26  -2.75  -6.79
# 196004   1.17 -2.16   1.35   6.46  -1.17  -1.27   0.21   1.49  -5.53  -1.10
# 196005   8.20 -0.52   2.44   7.28  11.67   7.74   1.74  13.50   3.40   2.10
# 196006   5.39  0.47   4.73   2.24   0.02   6.38  -1.59  -0.40   0.45   4.04
# 196007  -2.11 -0.79   4.60  -4.72   0.23  -0.60  -1.10  -3.99  -6.80  -3.14
# 196008   4.57  3.24   5.20   7.16   3.63   5.09   3.34   2.29   1.17  -0.84
# 196009  -3.88 -5.00  -2.09  -2.33  -6.20  -9.18  -4.23  -8.87  -6.70  -5.25
# 196010   1.02  0.54   3.87   0.11   2.38   6.48  -3.50  -3.71  -1.59  -3.06
# 196011   9.46  6.57   5.44  13.91  10.11   9.13   3.15   3.91   4.25   2.04
# 196012   4.51 -0.31   3.54   7.77   7.41   1.76   3.28   6.06   2.85   0.52
# 196101   4.70  5.23   8.77   0.56   9.47   4.36   5.94   5.86   6.46  11.21
# 196102   4.21  8.16   5.41  22.33   2.15   5.90   7.84   5.05   2.13   6.81
# 196103   4.64  2.55   5.60   7.18   4.77   6.34   3.08   3.60   0.92   5.92
# 196104  -1.39  1.40  -0.23  -2.21  -6.37   2.66   2.60  -0.47  -1.47  -5.31
# 196105   4.20  5.38   3.39  -3.91   2.71  -0.02   6.80   2.10   5.50   5.47
# 196106  -2.17 -3.12   3.97  -5.87  -3.85   3.43  -5.50  -3.58  -1.32  -3.36
# 196107   2.72  0.88   5.95  -1.21  -2.55   1.97   2.03   3.27   2.95   1.53
# 196108   4.92  3.20   7.74   0.89   0.89  10.45   5.21   3.70   2.35   5.77
# 196109  -0.62 -1.48  -0.07   1.24   0.75  -3.05  -1.14  -1.48  -4.45  -4.25
# 196110   3.73 -0.84   7.05  -5.26   0.99  -0.67   8.28   3.33   0.05   3.11
# 196111   5.28  4.47   8.03   0.25   3.75   4.51   5.30   3.12   2.49   7.37
# 196112  -3.69  1.41  -6.12   1.97  -3.66  -3.78   0.32  -2.21  -0.16  -1.17
# 196201  -6.67 -3.45  -4.28 -13.23  -3.44  -7.37  -5.89  -4.86  -4.76   0.57
# 196202  -0.25  0.28   0.68  -2.02  -0.52  -0.90   2.01   3.56   3.30   1.93
# 196203   0.98 -0.34  -6.67  -5.34   0.41   4.31  -1.18   0.34  -2.72  -0.74
# 196204  -4.59 -3.59 -12.99 -11.04  -8.74  -7.03  -8.01 -11.23  -6.23  -7.53
# 196205 -11.25 -9.05 -14.14 -11.39 -14.87 -10.19 -10.01 -11.14  -8.25  -7.50
# ...       ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 201507   4.03  3.51   9.59   6.09  -2.90   0.71   5.96   3.66  -4.90  -0.72
# 201508  -4.37 -3.12  -4.06  -7.35  -8.61  -6.94  -3.86  -8.37  -7.15  -3.11
# 201509  -1.19  2.58   2.37  -9.94  -5.32  -0.53   1.18  -7.28  -8.38  -5.92
# 201510   5.81  8.06  10.90  14.61  12.21   5.81   0.98   7.74  16.62   7.96
# 201511   0.11 -0.71  -3.00  -0.41  -1.17  -1.10  -1.08   0.71   1.68  -2.59
# 201512   1.96  0.30   1.59  -1.70  -6.18   1.86  -4.38   0.39  -4.82  -2.65
# 201601  -1.67 -0.23   4.28  -8.15  -5.28   0.16   1.52  -9.43 -11.10  -5.33
# 201602   0.95 -2.34   0.93   4.25  -0.96   0.34   0.81  -1.09   6.79   0.63
# 201603   4.69  5.61   5.04   8.61   6.88   4.65   2.30   2.90   8.33   3.58
# 201604   0.63  0.31  -0.25  -6.30   1.82  -0.42  -2.27   3.55   3.77   1.55
# 201605   2.06 -0.91   0.83   5.42  -0.53  -0.09  -4.96   2.46  -1.42  -1.70
# 201606   4.75  5.31   6.87  -4.43  -0.34   3.16   1.63   0.11  -1.14  -4.67
# 201607  -0.51  1.82  -2.79   6.15   7.38   2.58   1.62   6.00   4.29   8.39
# 201608  -0.52 -0.90  -1.22   0.94   0.29   1.24   1.37  -3.24   2.48   1.03
# 201609  -2.92  1.63  -2.78   4.62  -3.95   0.00  -6.92   0.35  -1.76  -4.87
# 201610  -0.33 -1.65   4.59   5.59 -10.28  -2.96  -5.76  -7.45  -1.95  -4.17
# 201611  -4.41 -5.76  -5.12   3.87   8.15  -4.18   1.80   1.37   7.55   1.58
# 201612   4.43  3.00   5.39  -3.36   1.98   1.43  -0.44   0.82   0.32  -1.27
# 201701   0.95 -1.02   5.61   4.84   1.60   2.72  -0.01   2.17   3.79   6.90
# 201702   1.71  6.13   7.93   0.65  -0.39   4.83   3.81   7.03   3.10  -2.12
# 201703   0.52  0.89   1.03   5.79  -0.92  -0.36   0.32  -0.19   2.17   1.94
# 201704   0.76  1.89  -0.14   2.74  -0.83  -0.36  -1.24   1.06   1.28   3.24
# 201705   1.63  4.28   6.12   2.80  -1.71   1.77  -2.17  -0.50  -0.63  -0.14
# 201706  -2.65 -1.20  -1.00  -0.20   2.69  -0.19   9.38   5.49   1.93   4.39
# 201707   1.52  1.18  -6.06   4.98   2.34   1.79   1.25   0.45   1.03   1.22
# 201708  -2.77  0.94  -0.96  -1.78  -6.37  -0.04  -5.79   1.69   1.52   2.62
# 201709   0.43 -3.00  -2.13   3.66   3.54  -0.21   1.01   1.40   6.58   0.45
# 201710   0.71  1.24  -2.90   2.02  -1.90  -3.09   3.47  -2.35   5.52   1.23
# 201711   4.15  4.33   1.34   3.30  10.00   4.55   7.94   2.28   2.17   3.80
# 201712  -0.10  4.31   4.87   0.80   1.06   2.31   4.65  -0.32   0.49  -1.77
#
#            ...      Telcm.lead  Servs.lead  BusEq.lead  Paper.lead  \
# yyyymm     ...
# 195912     ...            0.62       -6.18       -7.93       -9.41
# 196001     ...            8.07        9.13        5.09        3.00
# 196002     ...           -0.21       -0.31        3.34       -2.43
# 196003     ...           -1.24        7.14        1.77        0.41
# 196004     ...            3.05       -1.75       11.90        2.85
# 196005     ...           -0.58       -8.07        2.39        3.50
# 196006     ...           -0.03        2.84       -2.02       -4.10
# 196007     ...            6.94        5.69        2.71        1.18
# 196008     ...           -6.07       -3.53       -7.61       -7.37
# 196009     ...           -0.08        4.62       -3.40       -1.85
# 196010     ...            4.06        9.49        8.19        5.31
# 196011     ...           12.29        8.18        4.29        5.57
# 196012     ...            7.70        4.29        5.08        4.56
# 196101     ...            0.61        0.20        4.54        6.83
# 196102     ...            7.23       -0.20        2.31       -0.69
# 196103     ...            0.63       -0.12        2.19       -0.37
# 196104     ...           -1.22       -0.70        1.57        1.39
# 196105     ...           -4.19        0.13       -3.31       -4.46
# 196106     ...            6.25       -8.25        0.56       -0.50
# 196107     ...            0.12        8.99        5.11        5.37
# 196108     ...           -2.94       -6.04        1.01       -2.74
# 196109     ...            0.00        2.24        6.53        1.74
# 196110     ...            8.34        8.27        0.99        2.05
# 196111     ...            3.14       -0.68       -0.55       -2.65
# 196112     ...           -6.32       -4.88       -6.91       -5.22
# 196201     ...            3.89       -1.94       -0.07        3.87
# 196202     ...           -3.14       -1.41       -0.76        1.13
# 196203     ...           -4.93       -3.11      -12.01       -7.93
# 196204     ...           -7.35      -10.97      -13.19      -11.03
# 196205     ...           -8.72      -13.11      -12.59       -9.62
# ...        ...             ...         ...         ...         ...
# 201507     ...           -8.42       -5.29       -6.50       -5.69
# 201508     ...           -2.63       -1.47       -1.72       -2.66
# 201509     ...            8.84       11.26        8.16       10.19
# 201510     ...           -1.92        1.99        0.12       -0.02
# 201511     ...           -3.03       -1.19       -4.64       -3.75
# 201512     ...           -0.36       -5.09       -7.95       -5.27
# 201601     ...            1.15       -2.45        1.45        2.99
# 201602     ...            6.00        7.76        8.86        8.18
# 201603     ...            0.59       -2.55       -5.46        0.80
# 201604     ...            0.30        4.67        5.64        1.79
# 201605     ...            3.10       -2.12       -1.63        2.06
# 201606     ...            2.27        7.33        8.20        2.52
# 201607     ...           -3.56        1.19        2.38        2.46
# 201608     ...            0.52        0.82        4.33       -0.64
# 201609     ...           -2.85       -0.55       -2.24       -5.49
# 201610     ...            6.25       -0.01        2.39        4.21
# 201611     ...            4.65       -0.19        2.07        1.86
# 201612     ...            3.36        5.45        3.20        2.28
# 201701     ...           -0.11        3.23        6.99        3.21
# 201702     ...            0.81        1.81        2.45        0.26
# 201703     ...           -0.16        3.83        0.99        2.06
# 201704     ...           -2.00        3.60        4.57        2.60
# 201705     ...           -2.33       -0.82       -3.44        1.87
# 201706     ...            5.25        3.98        3.05       -2.42
# 201707     ...           -2.58        1.36        4.98        0.72
# 201708     ...           -1.68        0.60        0.80        2.44
# 201709     ...           -5.75        5.93        7.12        4.28
# 201710     ...            3.91        0.05        2.41        4.21
# 201711     ...            4.41        0.39       -0.89       -0.95
# 201712     ...            3.08        9.25        5.02        4.28
#
#         Trans.lead  Whlsl.lead  Rtail.lead  Meals.lead  Fin.lead  Other.lead
# yyyymm
# 195912       -4.31       -5.33       -6.09      -10.08     -4.68       -3.98
# 196001       -0.94        1.42        4.00        1.81     -0.98        6.32
# 196002       -4.99       -1.37       -0.13       -3.88      0.05       -2.43
# 196003       -2.13        0.45       -0.53        8.86     -0.64        0.55
# 196004        0.90        1.65        3.11        0.80     -0.45        1.02
# 196005        2.17        5.96        3.41        1.03      3.72        6.41
# 196006       -3.11       -6.16       -2.99       -1.25      0.09       -5.95
# 196007        1.98        4.51        2.85        2.05      3.47        3.48
# 196008       -7.07       -8.44       -8.57       -1.90     -5.78       -4.21
# 196009       -1.02       -4.22        0.31       -4.54     -0.40        0.38
# 196010        5.35        9.72        6.50        4.40      7.71        4.01
# 196011        2.27        2.06        2.05        2.08      5.56        3.80
# 196012        8.35        7.93        2.28        4.08      7.12        8.23
# 196101        4.22        3.31        4.82        8.23      7.00        6.00
# 196102        0.86        4.45        5.76        4.06      4.34        7.08
# 196103       -1.62        3.08        0.22        4.23      1.38       -3.67
# 196104        4.74       -0.04        4.31       -1.90      4.00        3.32
# 196105       -4.57       -4.90        0.80       -5.63     -2.88        0.37
# 196106       -0.32       -0.01        2.45        2.69      3.35        5.37
# 196107        3.52        3.09        3.03        0.46      8.65        1.64
# 196108       -1.16       -4.22        0.66       -6.21     -0.40        3.14
# 196109        2.16        4.30        9.35        0.71      2.02        0.39
# 196110        0.47        5.65        4.90        1.08      7.22        1.69
# 196111       -0.24        0.46       -0.63       -2.21     -4.44       -0.77
# 196112        2.52       -0.79       -9.56       -3.90     -4.99       -3.62
# 196201        0.32       -0.09        1.58       -0.59      3.59        4.20
# 196202       -1.68       -2.30        0.90       -4.07     -2.13       -1.83
# 196203       -6.27       -5.78       -4.61       -9.09     -7.69       -2.12
# 196204       -5.17      -11.34       -9.09       -7.46    -10.02      -11.83
# 196205       -7.81      -11.11      -10.43      -12.90    -11.01      -14.25
# ...            ...         ...         ...         ...       ...         ...
# 201507       -6.37       -4.13       -5.44       -6.48     -6.54       -5.20
# 201508       -0.71       -6.04       -1.75        0.44     -3.14       -1.87
# 201509        6.48        5.07        4.56        5.05      5.90        6.98
# 201510       -1.10        2.67        0.61       -1.01      2.16        0.05
# 201511       -5.02       -1.88        0.82       -0.95     -2.92        0.25
# 201512       -8.53       -8.68       -4.45       -0.94     -9.63       -3.20
# 201601        6.89        3.85       -0.36        1.03     -2.85        2.71
# 201602        6.86        6.18        5.99        5.36      6.65        6.68
# 201603       -1.08        0.49       -0.38       -2.38      3.96        0.67
# 201604       -2.18        1.78        1.19       -1.48      2.15       -2.02
# 201605       -2.53        1.81        0.71        1.16     -5.30        3.61
# 201606        5.39        3.65        3.78        2.19      4.04       -0.21
# 201607        1.09       -1.03       -1.69       -0.24      4.88        2.24
# 201608        2.86       -2.56       -0.18       -2.25     -1.45       -3.48
# 201609       -0.64       -8.18       -3.59       -1.96      1.40       -0.53
# 201610       12.75        9.29        2.99        8.47     12.84        8.29
# 201611        0.84        2.34       -0.98        0.58      3.80        2.57
# 201612        1.70        1.69        0.93        0.71      0.56       -0.87
# 201701        2.56        2.73        2.79        2.35      4.58        3.71
# 201702       -2.80       -1.29        0.80        2.73     -2.26       -1.83
# 201703        2.14       -2.96        3.21        4.30      0.18       -1.06
# 201704        2.68        2.56        0.45        6.93     -1.03       -0.74
# 201705        3.38        0.15       -2.45       -2.54      5.70        1.31
# 201706       -4.49       -0.99        0.93       -2.63      1.86        1.44
# 201707        0.60       -4.55       -1.81        1.26     -1.31        1.53
# 201708        6.20        4.46        2.71        0.79      5.07        0.99
# 201709       -1.99       -1.18        3.22        3.64      3.22       -1.20
# 201710        6.66        3.37        9.38        5.45      3.76        1.60
# 201711        2.73        4.21        2.45        1.18      0.88        1.14
# 201712        2.56        4.84       11.37        3.12      6.00        5.41
#
# [697 rows x 133 columns]

# %%
desc = data.describe()
desc
# min, max line up with Table 1
# Out:
#              Food        Beer       Smoke       Games       Books       Hshld  \
# count  697.000000  697.000000  697.000000  697.000000  697.000000  697.000000
# mean     0.688666    0.727030    0.985079    0.732095    0.532253    0.564333
# std      4.308660    5.058992    6.032324    7.128170    5.780362    4.728000
# min    -18.150000  -20.190000  -25.320000  -33.400000  -26.560000  -22.240000
# 25%     -1.630000   -2.080000   -2.740000   -3.390000   -2.600000   -2.030000
# 50%      0.740000    0.750000    1.270000    0.940000    0.510000    0.750000
# 75%      3.070000    3.690000    4.660000    5.260000    3.640000    3.540000
# max     19.890000   25.510000   32.380000   34.520000   33.130000   18.220000
#
#             Clths        Hlth       Chems       Txtls     ...      Telcm.lead  \
# count  697.000000  697.000000  697.000000  697.000000     ...      697.000000
# mean     0.690387    0.665825    0.552367    0.687145     ...        0.515968
# std      6.355251    4.897557    5.482363    6.970961     ...        4.607931
# min    -31.500000  -21.060000  -28.600000  -33.110000     ...      -16.440000
# 25%     -2.800000   -2.230000   -2.750000   -3.170000     ...       -2.110000
# 50%      0.700000    0.760000    0.720000    0.640000     ...        0.590000
# 75%      4.310000    3.550000    3.760000    4.480000     ...        3.360000
# max     31.790000   29.010000   21.680000   59.030000     ...       21.220000
#
#        Servs.lead  BusEq.lead  Paper.lead  Trans.lead  Whlsl.lead  Rtail.lead  \
# count  697.000000  697.000000  697.000000  697.000000  697.000000  697.000000
# mean     0.729928    0.622970    0.534806    0.601090    0.631076    0.698235
# std      6.486956    6.698787    5.021876    5.707154    5.571040    5.334178
# min    -28.670000  -32.070000  -27.740000  -28.500000  -29.250000  -29.740000
# 25%     -3.050000   -3.220000   -2.400000   -2.780000   -2.560000   -2.380000
# 50%      1.010000    0.670000    0.710000    0.900000    0.940000    0.540000
# 75%      4.260000    4.630000    3.460000    4.040000    3.880000    3.980000
# max     23.380000   24.660000   21.000000   18.500000   17.530000   26.490000
#
#        Meals.lead    Fin.lead  Other.lead
# count  697.000000  697.000000  697.000000
# mean     0.728766    0.637547    0.396628
# std      6.065564    5.381389    5.771655
# min    -31.890000  -22.530000  -28.090000
# 25%     -2.840000   -2.400000   -2.930000
# 50%      1.080000    0.870000    0.540000
# 75%      4.300000    4.000000    4.200000
# max     27.380000   20.590000   19.960000
#
# [8 rows x 133 columns]

# %%
# Run LASSO, then OLS on selected variables

# We get better R-squareds across the board in-sample, unsurprisingly

X = data.values[:-1,:npredictors]
Y = data.values[:-1,-nresponses:]
nrows = X.shape[0]
X.shape
# Out:
# (696, 103)

# %%
def subset_selection(X, Y, model_aic, verbose=False):
    
    global responses
    global response_reverse_dict
    global predictors
    global predictor_reverse_dict
    
    coef_dict = {}
    for response_index, response in enumerate(responses):
        y = Y[:,response_reverse_dict[response]]
        
        model_aic.fit(X, y)

        coef_dict[response] = [predstr for i, predstr in enumerate(predictors) if model_aic.coef_[i] !=0]
        #y_response = model_aic.responseict(X)
        # print ("In-sample LASSO R-squared: %.6f" % r2_score(y, y_response))
        if verbose:
            print("LASSO variables selected for %s: " % response)
            print(coef_dict[response])
        
        if not coef_dict[response]:
            if verbose:
                print("No coefs selected for " + response + ", using all")
                print("---")
            coef_dict[response] = predictors            
        # fit OLS vs. selected vars, better fit w/o LASSO penalties
        # in-sample R-squared using LASSO coeffs
        if verbose:
            print("Running OLS for " + response + " against " + str(coef_dict[response]))
            # col nums of selected responses
            predcols = [predictor_reverse_dict[predstr] for predstr in coef_dict[response]]
            model_ols = LinearRegression()
            model_ols.fit(X[:, predcols], y)
            y_pred = model_ols.predict(X[:, predcols])
            print ("In-sample OLS R-squared: %.2f%%" % (100 * r2_score(y, y_pred)))
            print("---")
            
    return coef_dict

coef_dict = subset_selection(X, Y, LassoLarsIC(criterion='aic'), verbose=True)
# Out:
# LASSO variables selected for Food.lead:
# ['10year', 'Mines.12m']
# Running OLS for Food.lead against ['10year', 'Mines.12m']
# In-sample OLS R-squared: 2.26%
# ---
# LASSO variables selected for Beer.lead:
# ['Food', 'Clths', 'Coal', '3month', '10year', 'Beer.3m', 'Hlth.3m', 'Util.3m', 'Mines.12m', 'Coal.12m', 'Servs.12m', '3month.12m']
# Running OLS for Beer.lead against ['Food', 'Clths', 'Coal', '3month', '10year', 'Beer.3m', 'Hlth.3m', 'Util.3m', 'Mines.12m', 'Coal.12m', 'Servs.12m', '3month.12m']
# In-sample OLS R-squared: 6.64%
# ---
# LASSO variables selected for Smoke.lead:
# ['Txtls', 'Carry', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', '3month', 'month', 'Food.3m', 'Beer.3m', 'Chems.3m', 'ElcEq.3m', 'Mines.3m', 'Servs.3m', 'Paper.3m', 'Other.3m', 'Food.12m', 'Smoke.12m', 'Games.12m', 'Hshld.12m', 'Hlth.12m', 'FabPr.12m', 'Paper.12m', '10year.12m']
# Running OLS for Smoke.lead against ['Txtls', 'Carry', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', '3month', 'month', 'Food.3m', 'Beer.3m', 'Chems.3m', 'ElcEq.3m', 'Mines.3m', 'Servs.3m', 'Paper.3m', 'Other.3m', 'Food.12m', 'Smoke.12m', 'Games.12m', 'Hshld.12m', 'Hlth.12m', 'FabPr.12m', 'Paper.12m', '10year.12m']
# In-sample OLS R-squared: 14.25%
# ---
# LASSO variables selected for Games.lead:
# ['Books', 'Fin']
# Running OLS for Games.lead against ['Books', 'Fin']
# In-sample OLS R-squared: 4.14%
# ---
# LASSO variables selected for Books.lead:
# ['Smoke', 'Games', 'Clths', 'Coal', 'Oil', 'Util', 'Servs', 'BusEq', 'Rtail', 'Meals', 'Fin', '3month', '10year', 'month', 'Chems.3m', 'Steel.3m', 'ElcEq.3m', 'Mines.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', '10year.3m', 'Beer.12m', 'Smoke.12m', 'Books.12m', 'Chems.12m', 'Steel.12m', 'FabPr.12m', 'Autos.12m', 'Carry.12m', 'Coal.12m', '3month.12m', 'curve.12m']
# Running OLS for Books.lead against ['Smoke', 'Games', 'Clths', 'Coal', 'Oil', 'Util', 'Servs', 'BusEq', 'Rtail', 'Meals', 'Fin', '3month', '10year', 'month', 'Chems.3m', 'Steel.3m', 'ElcEq.3m', 'Mines.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', '10year.3m', 'Beer.12m', 'Smoke.12m', 'Books.12m', 'Chems.12m', 'Steel.12m', 'FabPr.12m', 'Autos.12m', 'Carry.12m', 'Coal.12m', '3month.12m', 'curve.12m']
# In-sample OLS R-squared: 15.03%
# ---
# LASSO variables selected for Hshld.lead:
# ['Clths', 'Coal', '3month', 'Util.3m', 'Steel.12m', 'Coal.12m', '3month.12m']
# Running OLS for Hshld.lead against ['Clths', 'Coal', '3month', 'Util.3m', 'Steel.12m', 'Coal.12m', '3month.12m']
# In-sample OLS R-squared: 5.74%
# ---
# LASSO variables selected for Clths.lead:
# ['Clths', 'Coal', 'Oil', 'Servs', 'BusEq', 'Rtail', '10year', 'Steel.3m', 'ElcEq.3m', 'Util.3m', 'Paper.12m', '3month.12m']
# Running OLS for Clths.lead against ['Clths', 'Coal', 'Oil', 'Servs', 'BusEq', 'Rtail', '10year', 'Steel.3m', 'ElcEq.3m', 'Util.3m', 'Paper.12m', '3month.12m']
# In-sample OLS R-squared: 8.62%
# ---
# LASSO variables selected for Hlth.lead:
# ['Books', 'Clths', 'Mines', 'Coal', 'Util', '3month', 'Util.3m', 'Servs.3m', 'Paper.3m', 'Txtls.12m', 'Mines.12m', 'Coal.12m', '10year.12m']
# Running OLS for Hlth.lead against ['Books', 'Clths', 'Mines', 'Coal', 'Util', '3month', 'Util.3m', 'Servs.3m', 'Paper.3m', 'Txtls.12m', 'Mines.12m', 'Coal.12m', '10year.12m']
# In-sample OLS R-squared: 5.92%
# ---
# LASSO variables selected for Chems.lead:
# ['Clths', 'Autos', 'Carry', 'Coal', 'Oil', '3month', '10year', 'Smoke.3m', 'Autos.3m', 'Mines.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'FabPr.12m', 'Coal.12m', '10year.12m', 'curve.12m']
# Running OLS for Chems.lead against ['Clths', 'Autos', 'Carry', 'Coal', 'Oil', '3month', '10year', 'Smoke.3m', 'Autos.3m', 'Mines.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'FabPr.12m', 'Coal.12m', '10year.12m', 'curve.12m']
# In-sample OLS R-squared: 9.26%
# ---
# LASSO variables selected for Txtls.lead:
# ['Clths', 'Autos', 'Coal', 'Oil', 'BusEq', 'Rtail', 'Fin', '3month', 'Hshld.3m', 'Chems.3m', 'Txtls.3m', 'ElcEq.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Clths.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Coal.12m', 'Oil.12m', '3month.12m', 'curve.12m']
# Running OLS for Txtls.lead against ['Clths', 'Autos', 'Coal', 'Oil', 'BusEq', 'Rtail', 'Fin', '3month', 'Hshld.3m', 'Chems.3m', 'Txtls.3m', 'ElcEq.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Clths.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Coal.12m', 'Oil.12m', '3month.12m', 'curve.12m']
# In-sample OLS R-squared: 15.51%
# ---
# LASSO variables selected for Cnstr.lead:
# ['Clths', 'Coal', 'Oil', 'Servs', 'Trans', 'Fin', '3month', '10year', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Steel.12m', 'FabPr.12m', '10year.12m', 'curve.12m']
# Running OLS for Cnstr.lead against ['Clths', 'Coal', 'Oil', 'Servs', 'Trans', 'Fin', '3month', '10year', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Steel.12m', 'FabPr.12m', '10year.12m', 'curve.12m']
# In-sample OLS R-squared: 9.90%
# ---
# LASSO variables selected for Steel.lead:
# ['Fin', 'Smoke.12m']
# Running OLS for Steel.lead against ['Fin', 'Smoke.12m']
# In-sample OLS R-squared: 2.44%
# ---
# LASSO variables selected for FabPr.lead:
# ['Smoke', 'Coal', 'Oil', 'BusEq', 'Trans', 'Fin', '3month', '10year', 'Mines.3m', 'Coal.3m', 'Paper.3m', 'Food.12m', 'Beer.12m', 'FabPr.12m', '10year.12m', 'curve.12m']
# Running OLS for FabPr.lead against ['Smoke', 'Coal', 'Oil', 'BusEq', 'Trans', 'Fin', '3month', '10year', 'Mines.3m', 'Coal.3m', 'Paper.3m', 'Food.12m', 'Beer.12m', 'FabPr.12m', '10year.12m', 'curve.12m']
# In-sample OLS R-squared: 7.14%
# ---
# LASSO variables selected for ElcEq.lead:
# ['Fin', '3month']
# Running OLS for ElcEq.lead against ['Fin', '3month']
# In-sample OLS R-squared: 1.81%
# ---
# LASSO variables selected for Autos.lead:
# ['Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'ElcEq', 'Coal', 'Oil', 'Util', 'Servs', 'BusEq', 'Rtail', 'Meals', 'Fin', '10year', 'Food.3m', 'Beer.3m', 'Chems.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Paper.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'Smoke.12m', 'Chems.12m', 'FabPr.12m', 'Mines.12m', 'Coal.12m', 'Util.12m', 'Telcm.12m', 'Fin.12m', '3month.12m', 'curve.12m']
# Running OLS for Autos.lead against ['Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'ElcEq', 'Coal', 'Oil', 'Util', 'Servs', 'BusEq', 'Rtail', 'Meals', 'Fin', '10year', 'Food.3m', 'Beer.3m', 'Chems.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Paper.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'Smoke.12m', 'Chems.12m', 'FabPr.12m', 'Mines.12m', 'Coal.12m', 'Util.12m', 'Telcm.12m', 'Fin.12m', '3month.12m', 'curve.12m']
# In-sample OLS R-squared: 17.79%
# ---
# LASSO variables selected for Carry.lead:
# ['Trans']
# Running OLS for Carry.lead against ['Trans']
# In-sample OLS R-squared: 2.32%
# ---
# LASSO variables selected for Mines.lead:
# ['Carry', '3month', '10year.12m']
# Running OLS for Mines.lead against ['Carry', '3month', '10year.12m']
# In-sample OLS R-squared: 2.65%
# ---
# LASSO variables selected for Coal.lead:
# ['Beer', 'Smoke', 'Books', 'Oil', 'Paper', '3month', 'curve', 'month', 'Food.3m', 'Smoke.3m', 'Clths.3m', 'Mines.3m', 'Coal.3m', 'Util.3m', 'Telcm.3m', 'BusEq.3m', 'Rtail.3m', 'Other.3m', '10year.3m', 'Food.12m', 'Games.12m', 'Hlth.12m', 'Txtls.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Paper.12m', 'Trans.12m', '10year.12m']
# Running OLS for Coal.lead against ['Beer', 'Smoke', 'Books', 'Oil', 'Paper', '3month', 'curve', 'month', 'Food.3m', 'Smoke.3m', 'Clths.3m', 'Mines.3m', 'Coal.3m', 'Util.3m', 'Telcm.3m', 'BusEq.3m', 'Rtail.3m', 'Other.3m', '10year.3m', 'Food.12m', 'Games.12m', 'Hlth.12m', 'Txtls.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Paper.12m', 'Trans.12m', '10year.12m']
# In-sample OLS R-squared: 12.35%
# ---
# LASSO variables selected for Oil.lead:
# ['Beer', 'Smoke', 'Hshld', 'Hlth', 'Carry', 'Coal', '10year', 'Hshld.3m', 'Autos.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', '3month.3m', 'Clths.12m', 'Carry.12m']
# Running OLS for Oil.lead against ['Beer', 'Smoke', 'Hshld', 'Hlth', 'Carry', 'Coal', '10year', 'Hshld.3m', 'Autos.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', '3month.3m', 'Clths.12m', 'Carry.12m']
# In-sample OLS R-squared: 7.40%
# ---
# LASSO variables selected for Util.lead:
# ['Beer', 'Hlth', 'Cnstr', 'FabPr', 'Carry', 'Mines', 'Telcm', 'Whlsl', 'Fin', 'Other', '10year', 'month', 'Beer.3m', 'Cnstr.3m', 'Telcm.3m', 'Paper.3m', 'Other.3m', 'Games.12m', 'Hshld.12m', 'Clths.12m', 'Mines.12m', 'Telcm.12m', 'BusEq.12m', 'Meals.12m', 'curve.12m']
# Running OLS for Util.lead against ['Beer', 'Hlth', 'Cnstr', 'FabPr', 'Carry', 'Mines', 'Telcm', 'Whlsl', 'Fin', 'Other', '10year', 'month', 'Beer.3m', 'Cnstr.3m', 'Telcm.3m', 'Paper.3m', 'Other.3m', 'Games.12m', 'Hshld.12m', 'Clths.12m', 'Mines.12m', 'Telcm.12m', 'BusEq.12m', 'Meals.12m', 'curve.12m']
# In-sample OLS R-squared: 12.65%
# ---
# LASSO variables selected for Telcm.lead:
# ['Books', 'Oil', 'Util', 'Fin', 'month', 'Beer.3m', 'Txtls.3m', 'Carry.3m', 'FabPr.12m', 'Mines.12m', 'Coal.12m', 'Telcm.12m', 'curve.12m']
# Running OLS for Telcm.lead against ['Books', 'Oil', 'Util', 'Fin', 'month', 'Beer.3m', 'Txtls.3m', 'Carry.3m', 'FabPr.12m', 'Mines.12m', 'Coal.12m', 'Telcm.12m', 'curve.12m']
# In-sample OLS R-squared: 6.89%
# ---
# LASSO variables selected for Servs.lead:
# ['Smoke', 'Books', 'Hlth', 'FabPr', 'Mines', 'Oil', 'Util', 'Telcm', 'Fin', '3month', '10year', 'month', 'Food.3m', 'Steel.3m', 'Mines.3m', 'Telcm.3m', 'Paper.3m', '3month.3m', 'Smoke.12m', 'Clths.12m', 'Txtls.12m', 'Steel.12m', 'FabPr.12m', 'Carry.12m', 'Coal.12m', 'Telcm.12m', 'Servs.12m', 'Paper.12m', '3month.12m', 'curve.12m']
# Running OLS for Servs.lead against ['Smoke', 'Books', 'Hlth', 'FabPr', 'Mines', 'Oil', 'Util', 'Telcm', 'Fin', '3month', '10year', 'month', 'Food.3m', 'Steel.3m', 'Mines.3m', 'Telcm.3m', 'Paper.3m', '3month.3m', 'Smoke.12m', 'Clths.12m', 'Txtls.12m', 'Steel.12m', 'FabPr.12m', 'Carry.12m', 'Coal.12m', 'Telcm.12m', 'Servs.12m', 'Paper.12m', '3month.12m', 'curve.12m']
# In-sample OLS R-squared: 11.30%
# ---
# LASSO variables selected for BusEq.lead:
# ['Books', 'Util', '3month', '10year.3m', 'Smoke.12m', 'Txtls.12m', 'Steel.12m', 'Telcm.12m', '3month.12m']
# Running OLS for BusEq.lead against ['Books', 'Util', '3month', '10year.3m', 'Smoke.12m', 'Txtls.12m', 'Steel.12m', 'Telcm.12m', '3month.12m']
# In-sample OLS R-squared: 6.67%
# ---
# LASSO variables selected for Paper.lead:
# ['Books', 'Clths', 'ElcEq', 'Carry', 'Coal', 'Oil', 'BusEq', 'Trans', 'Rtail', 'Fin', '3month', '10year', 'Food.3m', 'Games.3m', 'Chems.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Rtail.3m', '10year.3m', 'Games.12m', 'Clths.12m', 'Steel.12m', 'FabPr.12m', 'Carry.12m', 'Coal.12m', 'Trans.12m', 'Meals.12m', '10year.12m', 'curve.12m']
# Running OLS for Paper.lead against ['Books', 'Clths', 'ElcEq', 'Carry', 'Coal', 'Oil', 'BusEq', 'Trans', 'Rtail', 'Fin', '3month', '10year', 'Food.3m', 'Games.3m', 'Chems.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Rtail.3m', '10year.3m', 'Games.12m', 'Clths.12m', 'Steel.12m', 'FabPr.12m', 'Carry.12m', 'Coal.12m', 'Trans.12m', 'Meals.12m', '10year.12m', 'curve.12m']
# In-sample OLS R-squared: 14.01%
# ---
# LASSO variables selected for Trans.lead:
# ['Beer', 'Books', 'Clths', 'Coal', 'Oil', 'Servs', 'Fin', 'Other', '3month', '10year', 'month', 'Beer.3m', 'Smoke.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Steel.12m', 'Paper.12m', 'Meals.12m', '10year.12m', 'curve.12m']
# Running OLS for Trans.lead against ['Beer', 'Books', 'Clths', 'Coal', 'Oil', 'Servs', 'Fin', 'Other', '3month', '10year', 'month', 'Beer.3m', 'Smoke.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Steel.12m', 'Paper.12m', 'Meals.12m', '10year.12m', 'curve.12m']
# In-sample OLS R-squared: 9.52%
# ---
# LASSO variables selected for Whlsl.lead:
# ['Books']
# Running OLS for Whlsl.lead against ['Books']
# In-sample OLS R-squared: 3.42%
# ---
# LASSO variables selected for Rtail.lead:
# ['Rtail', '3month', '10year', 'Util.3m', 'Mines.12m', '3month.12m', '10year.12m']
# Running OLS for Rtail.lead against ['Rtail', '3month', '10year', 'Util.3m', 'Mines.12m', '3month.12m', '10year.12m']
# In-sample OLS R-squared: 5.73%
# ---
# LASSO variables selected for Meals.lead:
# ['Books', 'Clths', 'Coal', 'Oil', 'Servs', 'Meals', '3month', 'Util.3m', 'Paper.3m', 'Paper.12m', '3month.12m', 'curve.12m']
# Running OLS for Meals.lead against ['Books', 'Clths', 'Coal', 'Oil', 'Servs', 'Meals', '3month', 'Util.3m', 'Paper.3m', 'Paper.12m', '3month.12m', 'curve.12m']
# In-sample OLS R-squared: 9.86%
# ---
# LASSO variables selected for Fin.lead:
# ['Books', 'Clths', 'Coal', 'Oil', 'Util', 'Fin', 'Other', '3month', '10year', 'Beer.3m', 'Coal.3m', 'Paper.3m', 'Rtail.3m', 'Books.12m', 'Chems.12m', 'FabPr.12m', 'Mines.12m', 'Coal.12m', 'Servs.12m', 'BusEq.12m', '10year.12m', 'curve.12m']
# Running OLS for Fin.lead against ['Books', 'Clths', 'Coal', 'Oil', 'Util', 'Fin', 'Other', '3month', '10year', 'Beer.3m', 'Coal.3m', 'Paper.3m', 'Rtail.3m', 'Books.12m', 'Chems.12m', 'FabPr.12m', 'Mines.12m', 'Coal.12m', 'Servs.12m', 'BusEq.12m', '10year.12m', 'curve.12m']
# In-sample OLS R-squared: 9.82%
# ---
# LASSO variables selected for Other.lead:
# ['Smoke', 'Clths', 'Oil', 'Trans', 'Fin', '3month', '10year', 'Coal.3m', 'Paper.3m', 'Books.12m', 'Coal.12m', '10year.12m', 'curve.12m']
# Running OLS for Other.lead against ['Smoke', 'Clths', 'Oil', 'Trans', 'Fin', '3month', '10year', 'Coal.3m', 'Paper.3m', 'Books.12m', 'Coal.12m', '10year.12m', 'curve.12m']
# In-sample OLS R-squared: 8.87%
# ---

# %%
def predict_with_subsets(X, Y, create_model, coef_dict, verbose=False):
    """similar output to subset_selection, but pass a model function and a dictionary, compute avg R-squared"""
    global responses
    global response_reverse_dict
    
    model = create_model()
    
    scores = []
    for response in responses:
        y = Y[:,response_reverse_dict[response]]

#        print("LASSO variables selected for %s: " % pred)
#        print(coef_dict[pred])
        
        if not coef_dict[response]:
            if verbose:
                print("No coefs selected for " + response)
 #           print("---")
            continue
        # fit model vs. selected vars, better fit w/o LASSO penalties
        # in-sample R-squared using LASSO coeffs
        #print("Running model for " + pred + " against " + str(coef_dict[pred]))
        # col nums of selected predictors
        predcols = [predictor_reverse_dict[predstr] for predstr in coef_dict[response]]
        model.fit(X[:, predcols], y)
        y_pred = model.predict(X[:, predcols])
        score = r2_score(y, y_pred)
        scores.append(score)
        if verbose:
            print ("In-sample R-squared: %.4f%% for %s against %s" % (score*100, response, str(coef_dict[response])))
#        print("---")
    
    if verbose:
        print("Mean R-squared: %.4f%%" % (100 * np.mean(np.array(scores))))
    return np.mean(np.array(scores))
    

predict_with_subsets(X, Y, LinearRegression, coef_dict, verbose=True)
# Out:
# In-sample R-squared: 2.2604% for Food.lead against ['10year', 'Mines.12m']
# In-sample R-squared: 6.6423% for Beer.lead against ['Food', 'Clths', 'Coal', '3month', '10year', 'Beer.3m', 'Hlth.3m', 'Util.3m', 'Mines.12m', 'Coal.12m', 'Servs.12m', '3month.12m']
# In-sample R-squared: 14.2499% for Smoke.lead against ['Txtls', 'Carry', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', '3month', 'month', 'Food.3m', 'Beer.3m', 'Chems.3m', 'ElcEq.3m', 'Mines.3m', 'Servs.3m', 'Paper.3m', 'Other.3m', 'Food.12m', 'Smoke.12m', 'Games.12m', 'Hshld.12m', 'Hlth.12m', 'FabPr.12m', 'Paper.12m', '10year.12m']
# In-sample R-squared: 4.1425% for Games.lead against ['Books', 'Fin']
# In-sample R-squared: 15.0344% for Books.lead against ['Smoke', 'Games', 'Clths', 'Coal', 'Oil', 'Util', 'Servs', 'BusEq', 'Rtail', 'Meals', 'Fin', '3month', '10year', 'month', 'Chems.3m', 'Steel.3m', 'ElcEq.3m', 'Mines.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', '10year.3m', 'Beer.12m', 'Smoke.12m', 'Books.12m', 'Chems.12m', 'Steel.12m', 'FabPr.12m', 'Autos.12m', 'Carry.12m', 'Coal.12m', '3month.12m', 'curve.12m']
# In-sample R-squared: 5.7365% for Hshld.lead against ['Clths', 'Coal', '3month', 'Util.3m', 'Steel.12m', 'Coal.12m', '3month.12m']
# In-sample R-squared: 8.6206% for Clths.lead against ['Clths', 'Coal', 'Oil', 'Servs', 'BusEq', 'Rtail', '10year', 'Steel.3m', 'ElcEq.3m', 'Util.3m', 'Paper.12m', '3month.12m']
# In-sample R-squared: 5.9187% for Hlth.lead against ['Books', 'Clths', 'Mines', 'Coal', 'Util', '3month', 'Util.3m', 'Servs.3m', 'Paper.3m', 'Txtls.12m', 'Mines.12m', 'Coal.12m', '10year.12m']
# In-sample R-squared: 9.2644% for Chems.lead against ['Clths', 'Autos', 'Carry', 'Coal', 'Oil', '3month', '10year', 'Smoke.3m', 'Autos.3m', 'Mines.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'FabPr.12m', 'Coal.12m', '10year.12m', 'curve.12m']
# In-sample R-squared: 15.5082% for Txtls.lead against ['Clths', 'Autos', 'Coal', 'Oil', 'BusEq', 'Rtail', 'Fin', '3month', 'Hshld.3m', 'Chems.3m', 'Txtls.3m', 'ElcEq.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Clths.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Coal.12m', 'Oil.12m', '3month.12m', 'curve.12m']
# In-sample R-squared: 9.9049% for Cnstr.lead against ['Clths', 'Coal', 'Oil', 'Servs', 'Trans', 'Fin', '3month', '10year', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Steel.12m', 'FabPr.12m', '10year.12m', 'curve.12m']
# In-sample R-squared: 2.4365% for Steel.lead against ['Fin', 'Smoke.12m']
# In-sample R-squared: 7.1356% for FabPr.lead against ['Smoke', 'Coal', 'Oil', 'BusEq', 'Trans', 'Fin', '3month', '10year', 'Mines.3m', 'Coal.3m', 'Paper.3m', 'Food.12m', 'Beer.12m', 'FabPr.12m', '10year.12m', 'curve.12m']
# In-sample R-squared: 1.8117% for ElcEq.lead against ['Fin', '3month']
# In-sample R-squared: 17.7888% for Autos.lead against ['Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'ElcEq', 'Coal', 'Oil', 'Util', 'Servs', 'BusEq', 'Rtail', 'Meals', 'Fin', '10year', 'Food.3m', 'Beer.3m', 'Chems.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Paper.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'Smoke.12m', 'Chems.12m', 'FabPr.12m', 'Mines.12m', 'Coal.12m', 'Util.12m', 'Telcm.12m', 'Fin.12m', '3month.12m', 'curve.12m']
# In-sample R-squared: 2.3244% for Carry.lead against ['Trans']
# In-sample R-squared: 2.6455% for Mines.lead against ['Carry', '3month', '10year.12m']
# In-sample R-squared: 12.3496% for Coal.lead against ['Beer', 'Smoke', 'Books', 'Oil', 'Paper', '3month', 'curve', 'month', 'Food.3m', 'Smoke.3m', 'Clths.3m', 'Mines.3m', 'Coal.3m', 'Util.3m', 'Telcm.3m', 'BusEq.3m', 'Rtail.3m', 'Other.3m', '10year.3m', 'Food.12m', 'Games.12m', 'Hlth.12m', 'Txtls.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Paper.12m', 'Trans.12m', '10year.12m']
# In-sample R-squared: 7.4004% for Oil.lead against ['Beer', 'Smoke', 'Hshld', 'Hlth', 'Carry', 'Coal', '10year', 'Hshld.3m', 'Autos.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', '3month.3m', 'Clths.12m', 'Carry.12m']
# In-sample R-squared: 12.6530% for Util.lead against ['Beer', 'Hlth', 'Cnstr', 'FabPr', 'Carry', 'Mines', 'Telcm', 'Whlsl', 'Fin', 'Other', '10year', 'month', 'Beer.3m', 'Cnstr.3m', 'Telcm.3m', 'Paper.3m', 'Other.3m', 'Games.12m', 'Hshld.12m', 'Clths.12m', 'Mines.12m', 'Telcm.12m', 'BusEq.12m', 'Meals.12m', 'curve.12m']
# In-sample R-squared: 6.8867% for Telcm.lead against ['Books', 'Oil', 'Util', 'Fin', 'month', 'Beer.3m', 'Txtls.3m', 'Carry.3m', 'FabPr.12m', 'Mines.12m', 'Coal.12m', 'Telcm.12m', 'curve.12m']
# In-sample R-squared: 11.3019% for Servs.lead against ['Smoke', 'Books', 'Hlth', 'FabPr', 'Mines', 'Oil', 'Util', 'Telcm', 'Fin', '3month', '10year', 'month', 'Food.3m', 'Steel.3m', 'Mines.3m', 'Telcm.3m', 'Paper.3m', '3month.3m', 'Smoke.12m', 'Clths.12m', 'Txtls.12m', 'Steel.12m', 'FabPr.12m', 'Carry.12m', 'Coal.12m', 'Telcm.12m', 'Servs.12m', 'Paper.12m', '3month.12m', 'curve.12m']
# In-sample R-squared: 6.6726% for BusEq.lead against ['Books', 'Util', '3month', '10year.3m', 'Smoke.12m', 'Txtls.12m', 'Steel.12m', 'Telcm.12m', '3month.12m']
# In-sample R-squared: 14.0106% for Paper.lead against ['Books', 'Clths', 'ElcEq', 'Carry', 'Coal', 'Oil', 'BusEq', 'Trans', 'Rtail', 'Fin', '3month', '10year', 'Food.3m', 'Games.3m', 'Chems.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Rtail.3m', '10year.3m', 'Games.12m', 'Clths.12m', 'Steel.12m', 'FabPr.12m', 'Carry.12m', 'Coal.12m', 'Trans.12m', 'Meals.12m', '10year.12m', 'curve.12m']
# In-sample R-squared: 9.5218% for Trans.lead against ['Beer', 'Books', 'Clths', 'Coal', 'Oil', 'Servs', 'Fin', 'Other', '3month', '10year', 'month', 'Beer.3m', 'Smoke.3m', 'Coal.3m', 'Util.3m', 'Paper.3m', 'Steel.12m', 'Paper.12m', 'Meals.12m', '10year.12m', 'curve.12m']
# In-sample R-squared: 3.4191% for Whlsl.lead against ['Books']
# In-sample R-squared: 5.7265% for Rtail.lead against ['Rtail', '3month', '10year', 'Util.3m', 'Mines.12m', '3month.12m', '10year.12m']
# In-sample R-squared: 9.8577% for Meals.lead against ['Books', 'Clths', 'Coal', 'Oil', 'Servs', 'Meals', '3month', 'Util.3m', 'Paper.3m', 'Paper.12m', '3month.12m', 'curve.12m']
# In-sample R-squared: 9.8219% for Fin.lead against ['Books', 'Clths', 'Coal', 'Oil', 'Util', 'Fin', 'Other', '3month', '10year', 'Beer.3m', 'Coal.3m', 'Paper.3m', 'Rtail.3m', 'Books.12m', 'Chems.12m', 'FabPr.12m', 'Mines.12m', 'Coal.12m', 'Servs.12m', 'BusEq.12m', '10year.12m', 'curve.12m']
# In-sample R-squared: 8.8683% for Other.lead against ['Smoke', 'Clths', 'Oil', 'Trans', 'Fin', '3month', '10year', 'Coal.3m', 'Paper.3m', 'Books.12m', 'Coal.12m', '10year.12m', 'curve.12m']
# Mean R-squared: 8.3305%
# 0.08330520917634218

# %%
coef_dict_all = {}
for response in responses:
    coef_dict_all[response] = predictors
predict_with_subsets(X, Y, LinearRegression, coef_dict_all, verbose=True)
# Out:
# In-sample R-squared: 16.6947% for Food.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 15.8931% for Beer.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 24.2182% for Smoke.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 17.2534% for Games.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 21.4274% for Books.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 15.9381% for Hshld.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 22.5258% for Clths.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 12.6408% for Hlth.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 19.6881% for Chems.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 24.3429% for Txtls.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 19.5591% for Cnstr.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 17.6956% for Steel.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 18.5548% for FabPr.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 18.9289% for ElcEq.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 21.4960% for Autos.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 18.5760% for Carry.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 16.5717% for Mines.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 21.9043% for Coal.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 18.0349% for Oil.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 23.3281% for Util.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 17.8103% for Telcm.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 17.1037% for Servs.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 19.6714% for BusEq.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 21.5174% for Paper.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 20.0075% for Trans.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 17.8838% for Whlsl.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 18.2524% for Rtail.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 17.9948% for Meals.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 18.5359% for Fin.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# In-sample R-squared: 21.0519% for Other.lead against ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth', 'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry', 'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper', 'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other', '3month', '10year', 'curve', 'month', 'Mkt-RF', 'Food.3m', 'Beer.3m', 'Smoke.3m', 'Games.3m', 'Books.3m', 'Hshld.3m', 'Clths.3m', 'Hlth.3m', 'Chems.3m', 'Txtls.3m', 'Cnstr.3m', 'Steel.3m', 'FabPr.3m', 'ElcEq.3m', 'Autos.3m', 'Carry.3m', 'Mines.3m', 'Coal.3m', 'Oil.3m', 'Util.3m', 'Telcm.3m', 'Servs.3m', 'BusEq.3m', 'Paper.3m', 'Trans.3m', 'Whlsl.3m', 'Rtail.3m', 'Meals.3m', 'Fin.3m', 'Other.3m', '3month.3m', '10year.3m', 'curve.3m', 'Mkt-RF.3m', 'Food.12m', 'Beer.12m', 'Smoke.12m', 'Games.12m', 'Books.12m', 'Hshld.12m', 'Clths.12m', 'Hlth.12m', 'Chems.12m', 'Txtls.12m', 'Cnstr.12m', 'Steel.12m', 'FabPr.12m', 'ElcEq.12m', 'Autos.12m', 'Carry.12m', 'Mines.12m', 'Coal.12m', 'Oil.12m', 'Util.12m', 'Telcm.12m', 'Servs.12m', 'BusEq.12m', 'Paper.12m', 'Trans.12m', 'Whlsl.12m', 'Rtail.12m', 'Meals.12m', 'Fin.12m', 'Other.12m', '3month.12m', '10year.12m', 'curve.12m', 'Mkt-RF.12m']
# Mean R-squared: 19.1700%
# 0.19170032993169955

# %%
def fit_predict(X, Y, model, coef_dict="all", npredict=1):
    """for backtest, train model using Y_list v. X using n-npredict rows
    generate npredict prediction Y_list using last npredict rows of X
    if npredict=1, fit using n-1 rows, return prediction using X for final row
    if npredict=12, fit using n-12 rows, return prediction using X for final 12 rows
    coef_dict = None -> perform subset selection at each timestep using subset_selection()
    coef_dict = 'all' -> use all predictors"""
    
    global responses
    global response_reverse_dict
    
    # keep last row to predict against
    X_predict = X[-npredict:]
    nrows, ncols = X.shape
    X_predict = X_predict.reshape(npredict,ncols)
    # fit on remaining rows
    X_fit = X[:-npredict]
    Y_fit = Y[:-npredict]

    # if no coef_dict select predictors into coef_dict
    if coef_dict is None:
        coef_dict = subset_selection(X_fit, Y_fit, LassoLarsIC(criterion='aic'))
    # if coef_dict == "all" use all predictors for each response        
    elif coef_dict == 'all':
        coef_dict = {}
        for response in responses:
            coef_dict[response]=predictors

    predictions = []
    for response in responses:
        if not coef_dict[response]:
            predictions.append([np.nan]*npredict)
            continue
        # column indexes to fit against each other
        predcols = [predictor_reverse_dict[predstr] for predstr in coef_dict[response]]
        responsecol = response_reverse_dict[response]
        #print("fitting on" + str(X_fit[:, predcols].shape))
        model.fit(X_fit[:, predcols], Y_fit[:,responsecol])
        #print("predicting on" + str(X_predict[:, predcols].shape))
        y_pred = model.predict(X_predict[:,predcols])        
        predictions.append(y_pred)
        
    return np.array(predictions).transpose()

X = data.values[:,:npredictors]
Y = data.values[:, -nresponses:]
print(X[684])
print(Y[684])
predictions = fit_predict(X[:685], Y[:685], LinearRegression(), coef_dict, 1)
print(predictions)
# Out:
# [ 4.43        3.          5.39       -3.36        1.98        1.43
#  -0.44        0.82        0.32       -1.27        0.16       -2.14
#  -0.15       -0.4         4.16        1.4        -1.8        -9.68
#   2.17        3.61        4.65       -0.19        2.07        1.86
#   0.84        2.34       -0.98        0.58        3.8         2.57
#   0.06        0.35        1.98        1.          1.82       -0.10333333
#  -1.47        1.62        2.03333333 -0.05       -1.90333333 -1.46666667
#  -1.75333333  1.97333333 -1.28666667  2.          5.24333333  2.73
#   1.06        2.58666667  4.13333333  3.52333333  0.80333333  2.92333333
#   0.04333333  2.68333333 -0.25        0.74        0.19333333  4.31666667
#   1.15       -0.52666667  2.36333333  6.01333333  3.44333333  0.07333333
#   0.28666667  1.7         1.55333333  0.59583333  0.49083333  1.31416667
#   1.43416667  0.43        0.4925     -0.775      -0.30416667  1.34666667
#  -0.4375      1.4625      3.66583333  2.84166667  1.36916667  0.79083333
#   1.50833333  4.0975      7.61        2.01166667  1.72333333  1.505
#   0.73416667  1.50333333  1.28916667  1.81        0.745       0.2525
#   0.795       1.7075      1.44416667  0.02333333  0.02083333  1.52416667
#   1.09416667]
# [ 9.500e-01 -1.020e+00  5.610e+00  4.840e+00  1.600e+00  2.720e+00
#  -1.000e-02  2.170e+00  3.790e+00  6.900e+00  3.850e+00  3.600e+00
#   4.640e+00  4.350e+00  5.180e+00  1.950e+00  1.237e+01 -5.360e+00
#  -4.370e+00  1.050e+00  3.360e+00  5.450e+00  3.200e+00  2.280e+00
#   1.700e+00  1.690e+00  9.300e-01  7.100e-01  5.600e-01 -8.700e-01]
# [[-0.54728951 -0.33375139  2.91982883  1.25832789 -0.07208353 -0.0621672
#   -0.15598742  0.41519913  0.10047422  1.26624423  0.88752863  0.68470988
#    0.96887904  0.87622269 -2.00914091  0.76996524  0.36007178 -0.28775085
#    0.79682412  0.81383778  0.90406921 -0.45244886  0.33411957  0.20687117
#    0.9594649   0.88546123 -0.90472329  0.7317489   0.50870382 -1.93971646]]

# %%
# first iteration will train up to including 196911
# will use 196912 to predict 197001
# 19701 will be first month of performance to use
# train on first 121 months up to 196912 (0:120), put first prediction in P[121] (122nd row)
# first month of performance will be 197002
FIRST_TRAIN_MONTHS = 121
FIRST_PREDICT_MONTH = FIRST_TRAIN_MONTHS # This is stupid but keeps my head straight

print(X[FIRST_TRAIN_MONTHS])
print(data.iloc[FIRST_TRAIN_MONTHS][:30])
# Out:
# [-3.34000000e+00 -1.95000000e+00 -7.59000000e+00 -7.76000000e+00
#  -1.20500000e+01 -7.50000000e+00 -5.69000000e+00 -7.71000000e+00
#  -7.37000000e+00 -5.26000000e+00 -9.84000000e+00 -6.31000000e+00
#  -7.15000000e+00 -6.89000000e+00 -9.35000000e+00 -1.24900000e+01
#  -2.34000000e+00 -7.70000000e-01 -1.21600000e+01 -4.83000000e+00
#  -3.16000000e+00 -1.11700000e+01 -9.73000000e+00 -8.89000000e+00
#  -8.17000000e+00 -8.28000000e+00 -6.31000000e+00 -1.31200000e+01
#  -9.78000000e+00 -6.20000000e+00  5.00000000e-02  1.40000000e-01
#  -8.00000000e-02  8.33333333e-02 -8.10000000e+00 -2.28666667e+00
#  -2.18000000e+00 -3.36000000e+00 -7.00333333e+00 -6.82000000e+00
#  -3.37666667e+00 -5.32666667e+00 -1.41000000e+00 -5.58666667e+00
#  -5.43333333e+00 -6.02666667e+00 -4.45000000e+00 -4.68333333e+00
#  -4.67666667e+00 -5.93666667e+00 -9.37000000e+00 -2.48000000e+00
#   2.38666667e+00 -6.98666667e+00 -3.96666667e+00 -2.88333333e+00
#  -4.91666667e+00 -4.43000000e+00 -4.87666667e+00 -8.43000000e+00
#  -6.69666667e+00 -4.78333333e+00 -7.30333333e+00 -6.68333333e+00
#  -6.49000000e+00  2.90000000e-01  2.30000000e-01 -1.16666667e-01
#  -4.84000000e+00 -9.10833333e-01 -2.67500000e-01 -1.33000000e+00
#  -2.70416667e+00 -2.59416667e+00 -5.53333333e-01 -3.83000000e+00
#   7.08333333e-01 -3.15416667e+00 -3.34500000e+00 -2.33333333e+00
#  -2.93750000e+00 -2.89416667e+00 -1.85166667e+00 -2.21083333e+00
#  -5.60750000e+00 -2.63666667e+00 -8.89166667e-01 -3.62333333e+00
#  -2.29916667e+00 -1.30000000e+00 -1.72083333e+00 -4.71666667e-01
#  -1.09000000e+00 -4.73666667e+00 -3.74666667e+00 -8.60833333e-01
#  -2.40916667e+00 -2.34833333e+00 -3.80000000e+00  1.44166667e-01
#   1.45833333e-01  5.83333333e-03 -1.98166667e+00]
# Food     -3.34
# Beer     -1.95
# Smoke    -7.59
# Games    -7.76
# Books   -12.05
# Hshld    -7.50
# Clths    -5.69
# Hlth     -7.71
# Chems    -7.37
# Txtls    -5.26
# Cnstr    -9.84
# Steel    -6.31
# FabPr    -7.15
# ElcEq    -6.89
# Autos    -9.35
# Carry   -12.49
# Mines    -2.34
# Coal     -0.77
# Oil     -12.16
# Util     -4.83
# Telcm    -3.16
# Servs   -11.17
# BusEq    -9.73
# Paper    -8.89
# Trans    -8.17
# Whlsl    -8.28
# Rtail    -6.31
# Meals   -13.12
# Fin      -9.78
# Other    -6.20
# Name: 197001, dtype: float64

# %%
# make predictions for all months in backtest period
# initial train_months = 120 -> train first model on 120 rows
# first prediction will be in P[120] (121st row)
# step = 6 -> predict following 6 rows, then step forward 6 months at a time
# initialize global predictions matrix P

def run_backtest(X, Y, create_model, coef_dict=None, initial_train_months=0, 
                 minmaxscale=False, standardscale=False, step=1, verbose=False):
    global P
    P = np.zeros_like(Y)

    count = 0
    nrows, ncols = Y.shape
    
    Xscale = X.copy()
    Yscale = Y.copy()
    
    if minmaxscale:
        # minmaxscale each row (min->0, max->1) - transpose, scale, transpose back because scales by columns
        Xscale = MinMaxScaler().fit_transform(Xscale.transpose()).transpose()
        Yscale = MinMaxScaler().fit_transform(Yscale.transpose()).transpose()
        print("using MinMaxScaler")
    elif standardscale:
        # standardize each row (mean->0, SD->1)- transpose, scale, transpose back because scales by columns
        Xscale = StandardScaler().fit_transform(Xscale.transpose()).transpose()
        Yscale = StandardScaler().fit_transform(Yscale.transpose()).transpose()
        print("using StandardScaler")
        
    # create list of steps
    month_indexes = list(range(initial_train_months+step, nrows, step))
    # force an iteration for last (nrows % step) rows
    if month_indexes[-1] < nrows: 
        month_indexes.append(nrows)
    if verbose:
        print("Initial train rows = %d" % initial_train_months)
        print ("Steps: " + str(month_indexes))

    model = create_model()
    
    for month_index in month_indexes:
        # if month_index =121 and step =1
        # train on 0:119 (120 rows)
        # fit on 120 (121st row)
        # if month_index = 1000 and step = 10
        # fit on 0:989, predict 990:999
        if verbose:
            print("Training on first %d rows (%d:%d), putting prediction in rows %s" % (month_index-step, 0, month_index-step-1, str(range(month_index-step,month_index))))
        predictions = fit_predict(Xscale[:month_index], 
                                  Yscale[:month_index], 
                                  model,
                                  coef_dict,
                                  step)
        #990
        first_pred_row = month_index-step
        for row_index in range(step):
            P[first_pred_row+row_index] = predictions[row_index]
            sys.stdout.write('.')
            count += 1
            if count % 80 == 0:
                print("")
                print("%s Still training %d of %d" % (time.strftime("%H:%M:%S"), count, (X.shape[0]-initial_train_months+1)))
            sys.stdout.flush()
    print("")

    msetemp = (P[initial_train_months:]-Yscale[initial_train_months:])**2
    #remove nans
    msetemp = msetemp[~np.isnan(msetemp)]
    mse = np.mean(msetemp)
    print("MSE across all predictions: %.4f" % mse)
    print("Variance: %.4f" % (np.mean(Yscale[initial_train_months:]**2)))
    print("R-squared: %.4f" % (1- mse/(np.mean(Yscale[initial_train_months:]**2))))

# %%
def gen_returns(Y, P, first_pred_month, start_date='01/01/1970', freq='M', verbose=False):
    #TODO: more general version
    #take an indicator (P), a function to generate portfolio based on indicator, universe returns (Y), return portfolio returns

    global R
    R = np.zeros(P.shape[0])
    nrows, ncols = P.shape
    numstocks = 6 # top quintile (and bottom)

    indcount = [0 for response in responses]
    longcount = [0 for response in responses]
    shortcount = [0 for response in responses]
        
    for month_index in range(first_pred_month, nrows):
        # get indexes of sorted smallest to largest
        # leftmost 6
        # ignore nan
        short_sort_array = [999999 if np.isnan(x) else x for x in P[month_index]]
        select_array = np.argsort(short_sort_array)
        short_indexes = select_array[:numstocks]
        # rightmost 6
        long_sort_array = [-999999 if np.isnan(x) else x for x in P[month_index]]
        select_array = np.argsort(long_sort_array)
        long_indexes = select_array[-numstocks:]
        # compute equal weighted long/short return
        return_month = month_index + 1
        if verbose:
            print("Longs for month %d: %s" %(return_month, str([(l,P[month_index, l]) for l in long_indexes])))
            print("Shorts for month %d: %s" %(return_month, str([(l,P[month_index, l]) for l in short_indexes])))
            
        if return_month < nrows: # last row has a prediction for following month but no following month
            R[return_month] = np.mean(X[return_month, long_indexes])/2 - np.mean(X[return_month, short_indexes])/2
            # count occurrences of each industry
            for i in short_indexes:
                indcount[i]+=1
                shortcount[i]+=1
            for i in long_indexes:
                indcount[i]+=1
                longcount[i]+=1

    for response in responses:
        i = response_reverse_dict[response]
        print("%s: long %d times, short %d times, total %d times" % (response, longcount[i], shortcount[i], indcount[i]))
        
    results = R[first_pred_month:]

    index = pd.date_range(start_date,periods=results.shape[0], freq=freq)
    perfdata = pd.DataFrame(results,index=index,columns=['Returns'])
    perfdata['Equity'] = 100 * np.cumprod(1 + results / 100)

    stats = perfdata['Equity'].calc_stats()

    retframe = pd.DataFrame([stats.stats.loc['start'],
                             stats.stats.loc['end'],
                             stats.stats.loc['cagr'],
                             stats.stats.loc['yearly_vol'],
                             stats.stats.loc['yearly_sharpe'],
                             stats.stats.loc['max_drawdown'],
                             ffn.core.calc_sortino_ratio(perfdata.Returns, rf=0, nperiods=564, annualize=False),
                            ],
                            index = ['start',
                                     'end',
                                     'cagr',
                                     'yearly_vol',
                                     'yearly_sharpe',
                                     'max_drawdown',
                                     'sortino',
                                    ],
                            columns=['Value'])   
    return retframe

# %%
# run linear regression for baseline
run_backtest(X, Y, LinearRegression, coef_dict, initial_train_months=FIRST_TRAIN_MONTHS)
gen_returns(X, P, FIRST_PREDICT_MONTH, verbose=False)

# this is even better than the paper (Sharpe 0.97)
# clearly there is impact from snooping, but we knew that
# (paper presumably uses theoretically snoop-free LASSO threshold)
# add a bunch of variables, select good ones using whole period, use the good ones in backtest
# more variables you add, better the result, more snooping effect, LASSO info leaks back into earlier performance

# OOS MSE of 39.5535 is worse, suggests overfitting
# But performance is better, suggests no overfitting. 
# Relationship between MSE/R-squared and performance seems tenuous, which is a little surprising.
# Out:
# ................................................................................
# 09:46:28 Still training 80 of 577
# ................................................................................
# 09:46:30 Still training 160 of 577
# ................................................................................
# 09:46:31 Still training 240 of 577
# ................................................................................
# 09:46:33 Still training 320 of 577
# ................................................................................
# 09:46:34 Still training 400 of 577
# ................................................................................
# 09:46:36 Still training 480 of 577
# ................................................................................
# 09:46:38 Still training 560 of 577
# ................
# MSE across all predictions: 39.6376
# Variance: 39.5535
# R-squared: -0.0021
# Food.lead: long 77 times, short 67 times, total 144 times
# Beer.lead: long 121 times, short 88 times, total 209 times
# Smoke.lead: long 160 times, short 149 times, total 309 times
# Games.lead: long 124 times, short 122 times, total 246 times
# Books.lead: long 133 times, short 143 times, total 276 times
# Hshld.lead: long 83 times, short 87 times, total 170 times
# Clths.lead: long 118 times, short 120 times, total 238 times
# Hlth.lead: long 140 times, short 95 times, total 235 times
# Chems.lead: long 93 times, short 89 times, total 182 times
# Txtls.lead: long 145 times, short 143 times, total 288 times
# Cnstr.lead: long 58 times, short 82 times, total 140 times
# Steel.lead: long 27 times, short 179 times, total 206 times
# FabPr.lead: long 80 times, short 85 times, total 165 times
# ElcEq.lead: long 49 times, short 58 times, total 107 times
# Autos.lead: long 175 times, short 184 times, total 359 times
# Carry.lead: long 90 times, short 82 times, total 172 times
# Mines.lead: long 97 times, short 62 times, total 159 times
# Coal.lead: long 204 times, short 227 times, total 431 times
# Oil.lead: long 164 times, short 127 times, total 291 times
# Util.lead: long 154 times, short 119 times, total 273 times
# Telcm.lead: long 103 times, short 90 times, total 193 times
# Servs.lead: long 141 times, short 214 times, total 355 times
# BusEq.lead: long 68 times, short 126 times, total 194 times
# Paper.lead: long 145 times, short 136 times, total 281 times
# Trans.lead: long 124 times, short 118 times, total 242 times
# Whlsl.lead: long 98 times, short 84 times, total 182 times
# Rtail.lead: long 77 times, short 64 times, total 141 times
# Meals.lead: long 139 times, short 120 times, total 259 times
# Fin.lead: long 152 times, short 81 times, total 233 times
# Other.lead: long 111 times, short 109 times, total 220 times
#                              Value
# start          1970-01-31 00:00:00
# end            2017-12-31 00:00:00
# cagr                     0.0888345
# yearly_vol               0.0971392
# yearly_sharpe             0.967051
# max_drawdown             -0.060131
# sortino                   0.841122

# %%
# double check results_post_LASSO
#model = LinearRegression()
#R = run_backtest(X, Y, model, coef_dict_paper, startmonth=STARTMONTH, summary=False)
results_post_LASSO = R[FIRST_PREDICT_MONTH:]
print(len(results_post_LASSO))
#print(results_post_LASSO)
print(np.mean(results_post_LASSO))
print(np.std(results_post_LASSO) * np.sqrt(12))
print(np.prod(1 + results_post_LASSO / 100))
print(np.prod(1 + results_post_LASSO / 100) ** (12.0/results_post_LASSO.shape[0]))-1
# Out:
# 576
# 0.7228370949074073
# 5.485195287590178
# 59.02450150561251
# 0.08867063021911337

# %%
# run performance chart
perf_post_LASSO = 100 * np.cumprod(1 + results_post_LASSO / 100)

def mychart(args, names=None):
    x_coords = np.linspace(1970, 2016, args[0].shape[0])
    
    plotdata = []
    for i in range(len(args)):
        tracelabel = "Trace %d" % i
        if names:
                tracelabel=names[i]
        plotdata.append(Scatter(x=x_coords,
                                y=args[i].reshape(-1),
                                mode = 'line',
                                name=tracelabel))    

    layout = Layout(
        autosize=False,
        width=600,
        height=480,
        yaxis=dict(
            type='log',
            autorange=True
        )
    )
    
    fig = Figure(data=plotdata, layout=layout)
    
    return iplot(fig)
    
mychart([perf_post_LASSO],["Post-LASSO"])
# Out:
# <div id="019ea494-4538-470f-baf8-b2d8c37f68c2" style="height: 480px; width: 600px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("019ea494-4538-470f-baf8-b2d8c37f68c2", [{"y": [100.0, 98.595, 97.09799925, 96.98390910088125, 98.6294027586262, 98.37461013483308, 98.72465978922952, 99.64197641977111, 101.66055679207497, 100.52704158384333, 101.68812891413673, 101.97624527939344, 102.84219356222428, 104.2725570710189, 104.91383329700568, 106.27159315625777, 107.47866133519094, 107.56106164221457, 107.66234830859432, 108.39086353214913, 108.96262533728121, 111.09193664074724, 111.65850551761505, 110.49074364740999, 112.11679909142104, 113.0342882306525, 113.12565761363895, 113.95147491421854, 114.55161934876676, 115.9921059620775, 117.46907211132793, 117.93209603723342, 119.58314538175469, 121.03807365056605, 121.0410996024073, 121.48189094012606, 125.08281665740964, 129.61706876124072, 130.91756001781187, 133.96903014589367, 136.77344851028104, 139.80639973099653, 134.9504574470066, 136.20887046269993, 138.0579058792311, 141.9350320693395, 148.64501071041752, 154.45703062919483, 149.84133969722572, 151.1849170431775, 149.84945027596277, 150.42262442326833, 150.36120185162883, 151.54780233624126, 149.03842330922365, 149.95252563885356, 151.33333847911132, 151.94371627764374, 155.48147247164155, 156.76678597740712, 152.13302106189158, 153.28669647161092, 159.7272925016931, 163.5114982732124, 165.72435388317655, 165.94808176091883, 166.93132414535225, 167.0036610524819, 170.15724685202292, 168.92644276645999, 172.21487751898042, 170.69077585293743, 165.59281134746305, 166.85131671370377, 166.29375523035213, 167.09473681804502, 169.5705238352324, 172.30767470747276, 173.7435719967017, 174.57319755298596, 175.6933755706176, 176.7211818177057, 177.50317304724902, 177.92326389012752, 178.95077073909303, 179.75754046384176, 181.3558845944661, 182.50144926548782, 183.5523534441749, 184.4257567259801, 186.858639833457, 186.22954907935105, 187.80474068198055, 189.11467874823734, 188.61037293824205, 189.3459533927012, 190.52778771846064, 189.62119299523363, 190.06048209233927, 191.93416167829957, 193.35607392606627, 193.0692624164093, 193.85119292919578, 193.96750364495327, 190.9205974418638, 194.99038817733287, 194.50941188649546, 197.17256991757472, 194.9510922965034, 194.0266992005308, 193.8795622869704, 191.73234613464223, 191.30733943404377, 195.14145736186774, 196.59688739802502, 194.71283389379394, 198.07974331320747, 198.39171890892578, 203.01259269517953, 205.6229962829184, 208.05106116402587, 212.26062763491132, 202.78672828813978, 204.59322005930662, 207.46775480113988, 210.09222189937432, 213.03351300596555, 216.60004906954043, 218.57471951689104, 213.90632779920944, 216.22899400856252, 215.37849329879552, 221.1416628153158, 221.8677446082261, 224.3267787776339, 223.59958613642976, 226.43371089070902, 225.4883501477403, 229.82712181849973, 230.6430081009554, 227.09879387647072, 224.09541232745437, 224.6295063935015, 223.5849791887717, 227.50889557353466, 232.87052187921768, 238.7000472769274, 242.0299129364405, 241.38449983527664, 244.62508674556523, 248.2108828087773, 248.13435111991126, 248.65543325726307, 253.43790609024444, 253.95111785007717, 246.83413777232875, 249.36830158679132, 238.68079179461742, 239.6514270145822, 245.47495669103654, 245.00650864868447, 248.99807301875262, 247.67008329598593, 246.13246486219, 246.79292030957023, 250.00328488126388, 244.39487785709423, 244.9814255639512, 252.58401580395247, 255.12038029598384, 255.96865556046797, 254.45417434840186, 256.8799708105233, 262.47139150849904, 269.05067438897873, 263.32437920239994, 265.9466511452905, 269.138010959034, 273.5047751868443, 275.31902352891706, 273.60286828225344, 270.9740007228415, 276.1586366033385, 276.29901724361184, 275.60826970050283, 278.1898004933642, 277.77715228929907, 278.487798837239 ...

# %%
# pass coef_dict as None
# fit_predict will do subset selection at each timestep using data it trains on
run_backtest(X, Y, LinearRegression, coef_dict=None, initial_train_months=FIRST_TRAIN_MONTHS)
gen_returns(X, P, FIRST_PREDICT_MONTH)

# Returns not as good as with fewer variables (unsurprisingly)
# Out:
# ................................................................................
# 09:47:42 Still training 80 of 577
# ................................................................................
# 09:48:35 Still training 160 of 577
# ................................................................................
# 09:49:25 Still training 240 of 577
# ................................................................................
# 09:50:11 Still training 320 of 577
# ................................................................................
# 09:50:56 Still training 400 of 577
# ................................................................................
# 09:51:41 Still training 480 of 577
# ................................................................................
# 09:52:26 Still training 560 of 577
# ................
# MSE across all predictions: 45.1396
# Variance: 39.5535
# R-squared: -0.1412
# Food.lead: long 75 times, short 72 times, total 147 times
# Beer.lead: long 110 times, short 121 times, total 231 times
# Smoke.lead: long 176 times, short 113 times, total 289 times
# Games.lead: long 132 times, short 127 times, total 259 times
# Books.lead: long 119 times, short 99 times, total 218 times
# Hshld.lead: long 88 times, short 81 times, total 169 times
# Clths.lead: long 115 times, short 129 times, total 244 times
# Hlth.lead: long 95 times, short 121 times, total 216 times
# Chems.lead: long 89 times, short 137 times, total 226 times
# Txtls.lead: long 162 times, short 96 times, total 258 times
# Cnstr.lead: long 70 times, short 108 times, total 178 times
# Steel.lead: long 89 times, short 188 times, total 277 times
# FabPr.lead: long 62 times, short 71 times, total 133 times
# ElcEq.lead: long 120 times, short 80 times, total 200 times
# Autos.lead: long 125 times, short 96 times, total 221 times
# Carry.lead: long 144 times, short 106 times, total 250 times
# Mines.lead: long 152 times, short 91 times, total 243 times
# Coal.lead: long 194 times, short 240 times, total 434 times
# Oil.lead: long 162 times, short 92 times, total 254 times
# Util.lead: long 127 times, short 153 times, total 280 times
# Telcm.lead: long 124 times, short 108 times, total 232 times
# Servs.lead: long 112 times, short 133 times, total 245 times
# BusEq.lead: long 86 times, short 126 times, total 212 times
# Paper.lead: long 113 times, short 129 times, total 242 times
# Trans.lead: long 77 times, short 102 times, total 179 times
# Whlsl.lead: long 123 times, short 107 times, total 230 times
# Rtail.lead: long 87 times, short 80 times, total 167 times
# Meals.lead: long 151 times, short 129 times, total 280 times
# Fin.lead: long 93 times, short 85 times, total 178 times
# Other.lead: long 78 times, short 130 times, total 208 times
#                              Value
# start          1970-01-31 00:00:00
# end            2017-12-31 00:00:00
# cagr                     0.0327433
# yearly_vol               0.0517068
# yearly_sharpe             0.639522
# max_drawdown             -0.138067
# sortino                    0.32085

# %%
results_LASSO_each_timestep = R[FIRST_PREDICT_MONTH:]
perf_LASSO_each_timestep = 100 * np.cumprod(1 + results_LASSO_each_timestep / 100)
mychart([perf_LASSO_each_timestep])
# Out:
# <div id="d6e5c223-81e3-4c6f-891a-f193c9c1397f" style="height: 480px; width: 600px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d6e5c223-81e3-4c6f-891a-f193c9c1397f", [{"y": [100.0, 102.72416666666666, 101.72945431944443, 104.22182595027081, 106.7283608643748, 109.73721123774295, 109.15011715762104, 108.86177893146298, 107.93101072159898, 106.7590598301803, 107.37915203602728, 107.41226060790505, 108.1095451996847, 109.65190804453353, 110.54831239279758, 108.8735054600467, 108.89346560271437, 110.45517938856663, 110.38062214247937, 109.06065386935889, 109.17153220079273, 108.98503083328303, 110.30011687200465, 110.89757583839469, 113.84283062336937, 115.96694810475039, 116.05488970706317, 115.75121274566303, 117.20099668530244, 118.627918819946, 118.99467680229768, 117.81563787964824, 116.26832583549553, 117.00856750998152, 116.59611230950884, 116.12875622600156, 118.61100839033234, 120.90613140268528, 121.80587453054024, 123.10615224115375, 125.13637786853079, 128.1615498035025, 122.35155954574373, 122.52081253644866, 123.13647961944432, 127.38981885296596, 132.83361044528272, 136.662539266368, 134.92806387217902, 136.97897044303616, 135.45622088827773, 136.5477722682691, 135.82634487145177, 138.116150668743, 136.8869169277912, 137.3101256459596, 138.9406833880054, 142.68050344919922, 142.96586445609762, 143.33757570368346, 143.1261527795205, 143.7189335956157, 144.12613724080327, 150.35478847189333, 150.87100657898017, 150.1279668715787, 149.15839041886642, 151.51757896065817, 152.8648227669167, 157.29535488011115, 158.01235953943964, 156.52309305078043, 153.18132501414627, 153.5757669260577, 152.29468907028283, 153.5993469066516, 153.9513454099793, 153.47922795072205, 154.05861203623604, 156.678892262619, 157.18287603273043, 156.4834122343848, 160.3446404312682, 158.86946973930054, 161.38357909792495, 162.79972000450925, 162.58536703983663, 161.01370849178488, 164.15884293099109, 164.30384990891343, 165.59226593194919, 163.7100338425227, 164.85463982913836, 164.59087240541172, 164.82952917039958, 165.43665126951052, 167.41775516846295, 168.7264039546964, 167.35831402929705, 168.41685536553234, 169.15929300293539, 167.88355000153825, 167.38829352903372, 169.82518810232722, 168.95624922320363, 169.7714631257056, 169.19848443765633, 170.44491327301375, 171.38236029601532, 171.68370761286914, 173.13300424463444, 173.9525004647257, 175.0759436968937, 177.93114054535056, 179.7149002293177, 180.9279758058656, 183.8394084832083, 181.32234058205904, 179.6179105805877, 182.84953615511677, 187.27906616847446, 189.74802852412884, 191.20434464305157, 189.12499739505836, 189.65297134611959, 189.94693345170606, 191.06762035907113, 192.82385023620492, 194.55926488833074, 194.18635963062812, 193.2121913931478, 193.22024190112253, 194.1315973754228, 194.08468223939042, 193.66901754492773, 192.8281712270868, 192.26736262910137, 191.34127483243788, 193.82552238401237, 195.19683795487924, 194.27290625522613, 195.77528339693322, 195.58766541701115, 193.99851563549794, 197.15099151457477, 200.14932951052558, 206.57745880997194, 208.99097212040175, 208.75934045963493, 211.6958885154338, 216.16267176310947, 211.55480414335918, 208.573644361639, 211.39807912903623, 216.9596102607893, 209.693271313805, 215.13131681654306, 215.21019829937575, 213.5997086487688, 216.73072437804532, 216.17986712025115, 220.042280746133, 215.84864161224627, 213.47970277055185, 210.75249956765805, 210.24493729786596, 208.55947371719475, 209.357213704163, 216.51025183905523, 219.1173961216172, 219.3474693875449, 216.19069372394245, 216.30239224903315, 214.89642669941443, 214.78897848606474, 209.42283384022122, 207.06682695951875, 203.7278743747965, 204.53259947857694, 206.63246749989034, 208.57309075716012, 207.0609358491707, 209.859709498732, 212.1926499359929, 211.31735525500693, 213.01141605296786, 215.6243560898843 ...

# %%
# pass coef_dict as 'all'
# fit_predict will use all predictors (no subset selection)
run_backtest(X, Y, LinearRegression, coef_dict='all', initial_train_months=FIRST_TRAIN_MONTHS)
gen_returns(X, P, FIRST_PREDICT_MONTH)
# Out:
# ................................................................................
# 09:52:40 Still training 80 of 577
# ................................................................................
# 09:52:45 Still training 160 of 577
# ................................................................................
# 09:52:50 Still training 240 of 577
# ................................................................................
# 09:52:55 Still training 320 of 577
# ................................................................................
# 09:53:00 Still training 400 of 577
# ................................................................................
# 09:53:06 Still training 480 of 577
# ................................................................................
# 09:53:11 Still training 560 of 577
# ................
# MSE across all predictions: 74.4120
# Variance: 39.5535
# R-squared: -0.8813
# Food.lead: long 109 times, short 60 times, total 169 times
# Beer.lead: long 114 times, short 115 times, total 229 times
# Smoke.lead: long 173 times, short 145 times, total 318 times
# Games.lead: long 164 times, short 152 times, total 316 times
# Books.lead: long 86 times, short 97 times, total 183 times
# Hshld.lead: long 90 times, short 97 times, total 187 times
# Clths.lead: long 132 times, short 114 times, total 246 times
# Hlth.lead: long 140 times, short 120 times, total 260 times
# Chems.lead: long 70 times, short 93 times, total 163 times
# Txtls.lead: long 144 times, short 136 times, total 280 times
# Cnstr.lead: long 57 times, short 37 times, total 94 times
# Steel.lead: long 112 times, short 164 times, total 276 times
# FabPr.lead: long 70 times, short 74 times, total 144 times
# ElcEq.lead: long 98 times, short 93 times, total 191 times
# Autos.lead: long 151 times, short 98 times, total 249 times
# Carry.lead: long 123 times, short 118 times, total 241 times
# Mines.lead: long 175 times, short 143 times, total 318 times
# Coal.lead: long 156 times, short 227 times, total 383 times
# Oil.lead: long 147 times, short 158 times, total 305 times
# Util.lead: long 158 times, short 133 times, total 291 times
# Telcm.lead: long 134 times, short 137 times, total 271 times
# Servs.lead: long 111 times, short 140 times, total 251 times
# BusEq.lead: long 93 times, short 139 times, total 232 times
# Paper.lead: long 73 times, short 65 times, total 138 times
# Trans.lead: long 77 times, short 116 times, total 193 times
# Whlsl.lead: long 92 times, short 94 times, total 186 times
# Rtail.lead: long 104 times, short 79 times, total 183 times
# Meals.lead: long 133 times, short 138 times, total 271 times
# Fin.lead: long 87 times, short 59 times, total 146 times
# Other.lead: long 77 times, short 109 times, total 186 times
#                              Value
# start          1970-01-31 00:00:00
# end            2017-12-31 00:00:00
# cagr                     0.0236823
# yearly_vol               0.0638839
# yearly_sharpe             0.400922
# max_drawdown             -0.209353
# sortino                   0.237134

# %%
results_OLS = R[FIRST_PREDICT_MONTH:]
perf_OLS = 100 * np.cumprod(1 + results_OLS / 100)
mychart([perf_OLS])
# Out:
# <div id="18cc515f-f1e4-4874-8f8c-cf33a7e5841a" style="height: 480px; width: 600px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("18cc515f-f1e4-4874-8f8c-cf33a7e5841a", [{"y": [100.0, 98.6575, 97.11679870833333, 100.99256828345173, 103.03430137224882, 102.82308105443572, 102.41264558922676, 102.57735926088279, 98.24773988874635, 101.23856483719294, 101.9252997686719, 102.20984123052612, 101.00376510400591, 100.81017455422324, 102.37105209023778, 102.69778636482579, 102.55229783414228, 103.59149445219494, 105.62706731818056, 104.34105777358171, 104.27758363010278, 104.31755670382765, 105.6215261626255, 105.20256077551376, 106.79287281923693, 107.54398269139888, 108.76729549451353, 109.5884885754971, 109.09351390209778, 109.47625031337095, 110.19331975292354, 111.27321428650221, 112.17730915258004, 112.13617747255743, 109.95512882071621, 110.24284474113043, 110.79865241670028, 113.58431520287682, 112.64345845861298, 115.84816485176053, 118.70478751673019, 121.52501542681517, 126.3951304200448, 126.29506760846228, 123.55656955915212, 125.61996427078996, 127.69583418036477, 128.1566033153656, 130.60439443868907, 130.977705332793, 130.01501919859697, 131.65104152351265, 132.1710631375305, 131.9463723301967, 129.02595928928835, 127.32711749197938, 127.67408388714503, 122.759695608189, 123.95967163275905, 122.41430772640398, 122.23374662250754, 124.96668947407576, 127.70970830803172, 132.50840059770601, 133.98807773771375, 132.0910298704106, 132.94191625449253, 133.07596602004912, 135.58223004676003, 138.3029134630317, 139.4807932760252, 138.72527231244672, 137.97731188589543, 137.70710631678554, 136.72479562505916, 134.74342546179264, 136.95995481063918, 137.51692529353576, 137.71747080958883, 137.79206777294402, 137.79091950571257, 136.57721115639973, 135.03616495718504, 134.2439527894362, 136.6569878408263, 137.1364261065012, 136.58445199142255, 136.85192987657243, 136.99106267194693, 138.0550265920324, 138.9385787622214, 139.26624224380228, 139.69216483466457, 140.19389252669575, 139.10271672986298, 140.03934168917735, 140.17938103086652, 140.28451556663967, 138.99389802342657, 139.6726515587743, 140.33027695986354, 140.12328980134774, 143.12776667350496, 142.96913339877514, 142.51401499078906, 141.24564025737104, 141.05142750201713, 142.40669663459903, 143.03921971215107, 145.281359481139, 146.52351510470277, 145.30126478287102, 143.26220370041807, 146.33279026639704, 146.0523190850531, 147.63333543914882, 145.95154569293786, 144.18309946429176, 144.4342183625254, 147.61778925893276, 150.32903598832183, 149.37945757766227, 149.92469259782072, 148.62034777221967, 148.0196738666403, 147.79887785312255, 148.3420387292328, 146.42471787865748, 148.25136623419374, 148.99632934952055, 147.8639572464642, 146.2312927185345, 148.03481199539644, 147.54136262207845, 145.57291494242887, 144.5733142598242, 145.45641625442798, 143.92669961015224, 147.24780820365652, 147.3840124262449, 146.97747819196917, 149.0841553793874, 148.59838950644289, 148.18726729547504, 153.21945991405056, 156.81245624903505, 157.38612848481276, 158.97441683143865, 161.94193927895884, 166.06471114976898, 171.12276547687236, 166.85895657040697, 165.99963294406936, 167.37466323695608, 167.68151678622385, 169.29684873126448, 174.1316845696148, 168.67120516098598, 168.33526834404034, 170.00459308845208, 174.9418098127292, 174.08022139940152, 175.41918843566523, 176.92779345621196, 173.82565947761304, 172.3568326550272, 169.67812021418035, 170.619833781369, 171.64497461600544, 172.55898410583566, 174.32915168445467, 173.06526533474238, 172.3239691148919, 167.6482454195745, 167.35206685266658, 165.26434981867956, 167.95127270614825, 166.91417359718776, 166.79733367566973, 170.27505808280745, 174.99877198578798, 175.39835251515555, 172.80245689793122, 173.07606078801962, 172.33183372663112, 172.97951420172038, 178.66189124 ...

# %%
mychart([perf_post_LASSO, perf_LASSO_each_timestep, perf_OLS],["Post-LASSO", "LASSO each timestep", "OLS"])
# Out:
# <div id="16e26978-c980-431a-b617-b5d9294588ad" style="height: 480px; width: 600px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("16e26978-c980-431a-b617-b5d9294588ad", [{"y": [100.0, 98.595, 97.09799925, 96.98390910088125, 98.6294027586262, 98.37461013483308, 98.72465978922952, 99.64197641977111, 101.66055679207497, 100.52704158384333, 101.68812891413673, 101.97624527939344, 102.84219356222428, 104.2725570710189, 104.91383329700568, 106.27159315625777, 107.47866133519094, 107.56106164221457, 107.66234830859432, 108.39086353214913, 108.96262533728121, 111.09193664074724, 111.65850551761505, 110.49074364740999, 112.11679909142104, 113.0342882306525, 113.12565761363895, 113.95147491421854, 114.55161934876676, 115.9921059620775, 117.46907211132793, 117.93209603723342, 119.58314538175469, 121.03807365056605, 121.0410996024073, 121.48189094012606, 125.08281665740964, 129.61706876124072, 130.91756001781187, 133.96903014589367, 136.77344851028104, 139.80639973099653, 134.9504574470066, 136.20887046269993, 138.0579058792311, 141.9350320693395, 148.64501071041752, 154.45703062919483, 149.84133969722572, 151.1849170431775, 149.84945027596277, 150.42262442326833, 150.36120185162883, 151.54780233624126, 149.03842330922365, 149.95252563885356, 151.33333847911132, 151.94371627764374, 155.48147247164155, 156.76678597740712, 152.13302106189158, 153.28669647161092, 159.7272925016931, 163.5114982732124, 165.72435388317655, 165.94808176091883, 166.93132414535225, 167.0036610524819, 170.15724685202292, 168.92644276645999, 172.21487751898042, 170.69077585293743, 165.59281134746305, 166.85131671370377, 166.29375523035213, 167.09473681804502, 169.5705238352324, 172.30767470747276, 173.7435719967017, 174.57319755298596, 175.6933755706176, 176.7211818177057, 177.50317304724902, 177.92326389012752, 178.95077073909303, 179.75754046384176, 181.3558845944661, 182.50144926548782, 183.5523534441749, 184.4257567259801, 186.858639833457, 186.22954907935105, 187.80474068198055, 189.11467874823734, 188.61037293824205, 189.3459533927012, 190.52778771846064, 189.62119299523363, 190.06048209233927, 191.93416167829957, 193.35607392606627, 193.0692624164093, 193.85119292919578, 193.96750364495327, 190.9205974418638, 194.99038817733287, 194.50941188649546, 197.17256991757472, 194.9510922965034, 194.0266992005308, 193.8795622869704, 191.73234613464223, 191.30733943404377, 195.14145736186774, 196.59688739802502, 194.71283389379394, 198.07974331320747, 198.39171890892578, 203.01259269517953, 205.6229962829184, 208.05106116402587, 212.26062763491132, 202.78672828813978, 204.59322005930662, 207.46775480113988, 210.09222189937432, 213.03351300596555, 216.60004906954043, 218.57471951689104, 213.90632779920944, 216.22899400856252, 215.37849329879552, 221.1416628153158, 221.8677446082261, 224.3267787776339, 223.59958613642976, 226.43371089070902, 225.4883501477403, 229.82712181849973, 230.6430081009554, 227.09879387647072, 224.09541232745437, 224.6295063935015, 223.5849791887717, 227.50889557353466, 232.87052187921768, 238.7000472769274, 242.0299129364405, 241.38449983527664, 244.62508674556523, 248.2108828087773, 248.13435111991126, 248.65543325726307, 253.43790609024444, 253.95111785007717, 246.83413777232875, 249.36830158679132, 238.68079179461742, 239.6514270145822, 245.47495669103654, 245.00650864868447, 248.99807301875262, 247.67008329598593, 246.13246486219, 246.79292030957023, 250.00328488126388, 244.39487785709423, 244.9814255639512, 252.58401580395247, 255.12038029598384, 255.96865556046797, 254.45417434840186, 256.8799708105233, 262.47139150849904, 269.05067438897873, 263.32437920239994, 265.9466511452905, 269.138010959034, 273.5047751868443, 275.31902352891706, 273.60286828225344, 270.9740007228415, 276.1586366033385, 276.29901724361184, 275.60826970050283, 278.1898004933642, 277.77715228929907, 278.487798837239 ...

# %%
def walkforward_xval (X, Y, create_model, coef_dict="all", n_splits=5):

    start = time.time()

    # generate k-folds
    kf = KFold(n_splits=n_splits)
    kf.get_n_splits(X)
    last_indexes = []
    for train_index, test_index in kf.split(X):
        # use test_index as last index to train
        last_index = test_index[-1] + 1
        last_indexes.append(last_index)
    print("%s Generate splits %s" % (time.strftime("%H:%M:%S"), str([i for i in last_indexes])))

    print("%s Starting training" % (time.strftime("%H:%M:%S")))
    model = create_model()
    avg_bests = []
    for i in range(1, n_splits-1):

        models = []
        losses = []
        scores = []
        count = 0        
        # skip kfold 0 so you start with train 2x size of eval set
        last_train_index = last_indexes[i]
        last_xval_index = last_indexes[i+1]

        # set up train, xval
        # train from beginning to last_train_index        
        print("Training indexes 0 to %d" % (last_train_index-1))
        X_fit = X[:last_train_index]
        Y_fit = Y[:last_train_index]
        # xval from last_train_index to last_xval_index
        print("Cross-validating indexes %d to %d" % (last_train_index, last_xval_index -1 ))
        X_xval = X[last_train_index:last_xval_index]
        Y_xval = Y[last_train_index:last_xval_index]

        if coef_dict is None:
            print("Performing LASSO subset selection on training set")
            coef_dict = subset_selection(X_fit, Y_fit, LassoLarsIC(criterion='aic'), verbose=False)
        elif coef_dict == 'all':
            # if coef_dict == "all" use all predictors for each response
            coef_dict = {}
            for response in responses:
                coef_dict[response]=predictors
                
        mse_list = []
        
        for response in responses:
            predcols = [predictor_reverse_dict[indstr] for indstr in coef_dict[response]]
            if len(predcols) == 0:
                continue
            responsecol = response_reverse_dict[response]
            
            fit = model.fit(X_fit[:,predcols], Y_fit[:,responsecol])
            # evaluate ... run prediction, calc MSE by industry, and average
            y_xval_pred = fit.predict(X_xval[:,predcols])
            mse_list.append(mean_squared_error(Y_xval[:,i], y_xval_pred))
            sys.stdout.write('.')
            count += 1
            if count % 80 == 0:
                print("")
                print("%s Still training" % (time.strftime("%H:%M:%S")))
            sys.stdout.flush()             
        # mean mse over industry ys for this fold
        xval_score = np.mean(np.array(mse_list))            

        # choose model with lowest xval loss
        print ("\n%s Xval MSE %f" % (time.strftime("%H:%M:%S"), xval_score))
        avg_bests.append(xval_score)
    
    print ("Last Xval loss %f" % (xval_score))
    # mean over folds
    avg_loss = np.mean(np.array(avg_bests))
    print ("Avg Xval loss %f" % avg_loss)
    print("--------------------------------------------------------------------------------")
    return (avg_loss, model)

# %%
# get baseline using linear regression
walkforward_xval (X, Y, LinearRegression, coef_dict=coef_dict)
# Out:
# 01:19:12 Generate splits [140, 280, 419, 558, 697]
# 01:19:12 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:19:12 Xval MSE 31.315901
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:19:12 Xval MSE 69.570862
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:19:12 Xval MSE 63.481511
# Last Xval loss 63.481511
# Avg Xval loss 54.789425
# --------------------------------------------------------------------------------
# (54.78942458318909,
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))

# %%
# closure to wrap model creation function - return a function to create model
def create_model(n_hidden_layers, layer_size, reg_penalty):
    def create_func():
        return MLPRegressor(hidden_layer_sizes=tuple([layer_size]*n_hidden_layers),
                            alpha=reg_penalty,
                            activation='tanh',
                            max_iter=10000, 
                            tol=1e-10,
                            solver='lbfgs')
    return create_func

# %%
walkforward_xval (X, Y, create_model(3,2,1.0), coef_dict=coef_dict)
# Out:
# 01:19:12 Generate splits [140, 280, 419, 558, 697]
# 01:19:12 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:19:39 Xval MSE 35.344126
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:20:12 Xval MSE 71.362061
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:20:43 Xval MSE 65.345100
# Last Xval loss 65.345100
# Avg Xval loss 57.350429
# --------------------------------------------------------------------------------
# (57.35042904355612,
#  MLPRegressor(activation='tanh', alpha=1.0, batch_size='auto', beta_1=0.9,
#         beta_2=0.999, early_stopping=False, epsilon=1e-08,
#         hidden_layer_sizes=(2, 2, 2), learning_rate='constant',
#         learning_rate_init=0.001, max_iter=10000, momentum=0.9,
#         nesterovs_momentum=True, power_t=0.5, random_state=None,
#         shuffle=True, solver='lbfgs', tol=1e-10, validation_fraction=0.1,
#         verbose=False, warm_start=False))

# %%
def run_experiment(X, Y, 
                   n_hidden_layers, 
                   layer_size, 
                   reg_penalty,
                   coef_dict="all", 
                   minmaxscale=False, 
                   standardscale=False):
    
    Xscale = X.copy()
    Yscale = Y.copy()
    
    if minmaxscale:
        # minmaxscale each row (min->0, max->1) - transpose, scale, transpose back because scales by columns
        Xscale = MinMaxScaler().fit_transform(Xscale.transpose()).transpose()
        Yscale = MinMaxScaler().fit_transform(Yscale.transpose()).transpose()
        print("using MinMaxScaler")
    elif standardscale:
        # standardize each row (mean->0, SD->1)- transpose, scale, transpose back because scales by columns
        Xscale = StandardScaler().fit_transform(Xscale.transpose()).transpose()
        Yscale = StandardScaler().fit_transform(Yscale.transpose()).transpose()
        print("using StandardScaler")

    return walkforward_xval(Xscale, Yscale, 
                            create_model(n_hidden_layers, layer_size, reg_penalty), 
                            coef_dict=coef_dict)

# %%
# try many combos

n_hiddens = [1, 2, 3]
layer_sizes = [1, 2, 4, 8]
reg_penalties = [0.0, 0.001, 0.01, 0.1, 1]
hyperparameter_combos = list(product(n_hiddens, layer_sizes, reg_penalties))

print("%s Running %d experiments" % (time.strftime("%H:%M:%S"), len(hyperparameter_combos)))
experiments = {}
        
for counter, param_list in enumerate(hyperparameter_combos):
    n_hidden_layers, layer_size, reg_penalty = param_list
    print("%s Running experiment %d of %d" % (time.strftime("%H:%M:%S"), counter+1, len(hyperparameter_combos)))
    key = (n_hidden_layers, layer_size, reg_penalty)
    print("%s n_hidden_layers = %d, hidden_layer_size = %d, reg_penalty = %.6f" % 
          (time.strftime("%H:%M:%S"), n_hidden_layers, layer_size, reg_penalty))    
    score, model = run_experiment (X, Y, n_hidden_layers, layer_size, reg_penalty)
    experiments[key] = score
# Out:
# 01:20:43 Running 60 experiments
# 01:20:43 Running experiment 1 of 60
# 01:20:43 n_hidden_layers = 1, hidden_layer_size = 1, reg_penalty = 0.000000
# 01:20:43 Generate splits [140, 280, 419, 558, 697]
# 01:20:43 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:20:47 Xval MSE 33.841702
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:20:52 Xval MSE 70.716246
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:20:55 Xval MSE 65.850293
# Last Xval loss 65.850293
# Avg Xval loss 56.802747
# --------------------------------------------------------------------------------
# 01:20:55 Running experiment 2 of 60
# 01:20:55 n_hidden_layers = 1, hidden_layer_size = 1, reg_penalty = 0.001000
# 01:20:55 Generate splits [140, 280, 419, 558, 697]
# 01:20:55 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:20:59 Xval MSE 33.857558
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:21:02 Xval MSE 69.925564
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:21:06 Xval MSE 65.198707
# Last Xval loss 65.198707
# Avg Xval loss 56.327276
# --------------------------------------------------------------------------------
# 01:21:06 Running experiment 3 of 60
# 01:21:06 n_hidden_layers = 1, hidden_layer_size = 1, reg_penalty = 0.010000
# 01:21:06 Generate splits [140, 280, 419, 558, 697]
# 01:21:06 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:21:13 Xval MSE 34.142679
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:21:19 Xval MSE 70.261846
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:21:26 Xval MSE 66.685887
# Last Xval loss 66.685887
# Avg Xval loss 57.030138
# --------------------------------------------------------------------------------
# 01:21:26 Running experiment 4 of 60
# 01:21:26 n_hidden_layers = 1, hidden_layer_size = 1, reg_penalty = 0.100000
# 01:21:26 Generate splits [140, 280, 419, 558, 697]
# 01:21:26 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:21:41 Xval MSE 37.411282
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:21:51 Xval MSE 72.265474
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:22:00 Xval MSE 66.176468
# Last Xval loss 66.176468
# Avg Xval loss 58.617741
# --------------------------------------------------------------------------------
# 01:22:00 Running experiment 5 of 60
# 01:22:00 n_hidden_layers = 1, hidden_layer_size = 1, reg_penalty = 1.000000
# 01:22:00 Generate splits [140, 280, 419, 558, 697]
# 01:22:00 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:22:09 Xval MSE 39.516299
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:22:17 Xval MSE 73.796698
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:22:23 Xval MSE 67.352855
# Last Xval loss 67.352855
# Avg Xval loss 60.221951
# --------------------------------------------------------------------------------
# 01:22:23 Running experiment 6 of 60
# 01:22:23 n_hidden_layers = 1, hidden_layer_size = 2, reg_penalty = 0.000000
# 01:22:23 Generate splits [140, 280, 419, 558, 697]
# 01:22:23 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:22:34 Xval MSE 39.483207
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:22:53 Xval MSE 78.758657
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:23:15 Xval MSE 72.121020
# Last Xval loss 72.121020
# Avg Xval loss 63.454295
# --------------------------------------------------------------------------------
# 01:23:15 Running experiment 7 of 60
# 01:23:15 n_hidden_layers = 1, hidden_layer_size = 2, reg_penalty = 0.001000
# 01:23:15 Generate splits [140, 280, 419, 558, 697]
# 01:23:15 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:23:28 Xval MSE 38.231679
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:23:42 Xval MSE 75.692466
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:23:59 Xval MSE 71.959707
# Last Xval loss 71.959707
# Avg Xval loss 61.961284
# --------------------------------------------------------------------------------
# 01:23:59 Running experiment 8 of 60
# 01:23:59 n_hidden_layers = 1, hidden_layer_size = 2, reg_penalty = 0.010000
# 01:23:59 Generate splits [140, 280, 419, 558, 697]
# 01:23:59 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:24:14 Xval MSE 38.655603
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:24:35 Xval MSE 75.781265
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:24:58 Xval MSE 72.316336
# Last Xval loss 72.316336
# Avg Xval loss 62.251068
# --------------------------------------------------------------------------------
# 01:24:58 Running experiment 9 of 60
# 01:24:58 n_hidden_layers = 1, hidden_layer_size = 2, reg_penalty = 0.100000
# 01:24:58 Generate splits [140, 280, 419, 558, 697]
# 01:24:58 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:25:51 Xval MSE 57.845276
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:26:47 Xval MSE 106.191652
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:27:30 Xval MSE 73.584832
# Last Xval loss 73.584832
# Avg Xval loss 79.207253
# --------------------------------------------------------------------------------
# 01:27:30 Running experiment 10 of 60
# 01:27:30 n_hidden_layers = 1, hidden_layer_size = 2, reg_penalty = 1.000000
# 01:27:30 Generate splits [140, 280, 419, 558, 697]
# 01:27:30 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:28:12 Xval MSE 66.133699
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:28:56 Xval MSE 107.363456
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:29:23 Xval MSE 77.322702
# Last Xval loss 77.322702
# Avg Xval loss 83.606619
# --------------------------------------------------------------------------------
# 01:29:23 Running experiment 11 of 60
# 01:29:23 n_hidden_layers = 1, hidden_layer_size = 4, reg_penalty = 0.000000
# 01:29:23 Generate splits [140, 280, 419, 558, 697]
# 01:29:23 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:29:45 Xval MSE 50.332653
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:30:19 Xval MSE 84.790238
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:31:00 Xval MSE 84.583933
# Last Xval loss 84.583933
# Avg Xval loss 73.235608
# --------------------------------------------------------------------------------
# 01:31:00 Running experiment 12 of 60
# 01:31:00 n_hidden_layers = 1, hidden_layer_size = 4, reg_penalty = 0.001000
# 01:31:00 Generate splits [140, 280, 419, 558, 697]
# 01:31:00 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:31:30 Xval MSE 52.471977
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:32:08 Xval MSE 88.165335
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:32:51 Xval MSE 82.960413
# Last Xval loss 82.960413
# Avg Xval loss 74.532575
# --------------------------------------------------------------------------------
# 01:32:51 Running experiment 13 of 60
# 01:32:51 n_hidden_layers = 1, hidden_layer_size = 4, reg_penalty = 0.010000
# 01:32:51 Generate splits [140, 280, 419, 558, 697]
# 01:32:51 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:33:29 Xval MSE 55.254436
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:34:31 Xval MSE 97.617895
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:35:34 Xval MSE 83.401774
# Last Xval loss 83.401774
# Avg Xval loss 78.758035
# --------------------------------------------------------------------------------
# 01:35:34 Running experiment 14 of 60
# 01:35:34 n_hidden_layers = 1, hidden_layer_size = 4, reg_penalty = 0.100000
# 01:35:34 Generate splits [140, 280, 419, 558, 697]
# 01:35:34 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:36:36 Xval MSE 95.642854
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:37:47 Xval MSE 118.064865
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:39:00 Xval MSE 90.089261
# Last Xval loss 90.089261
# Avg Xval loss 101.265660
# --------------------------------------------------------------------------------
# 01:39:00 Running experiment 15 of 60
# 01:39:00 n_hidden_layers = 1, hidden_layer_size = 4, reg_penalty = 1.000000
# 01:39:00 Generate splits [140, 280, 419, 558, 697]
# 01:39:00 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:40:03 Xval MSE 95.400734
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:41:14 Xval MSE 136.519086
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:42:31 Xval MSE 107.122225
# Last Xval loss 107.122225
# Avg Xval loss 113.014015
# --------------------------------------------------------------------------------
# 01:42:31 Running experiment 16 of 60
# 01:42:31 n_hidden_layers = 1, hidden_layer_size = 8, reg_penalty = 0.000000
# 01:42:31 Generate splits [140, 280, 419, 558, 697]
# 01:42:31 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:43:32 Xval MSE 77.501794
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:44:54 Xval MSE 111.616059
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:46:39 Xval MSE 102.335370
# Last Xval loss 102.335370
# Avg Xval loss 97.151074
# --------------------------------------------------------------------------------
# 01:46:39 Running experiment 17 of 60
# 01:46:39 n_hidden_layers = 1, hidden_layer_size = 8, reg_penalty = 0.001000
# 01:46:39 Generate splits [140, 280, 419, 558, 697]
# 01:46:39 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:47:36 Xval MSE 68.767853
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:49:05 Xval MSE 121.645770
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:50:50 Xval MSE 107.206195
# Last Xval loss 107.206195
# Avg Xval loss 99.206606
# --------------------------------------------------------------------------------
# 01:50:50 Running experiment 18 of 60
# 01:50:50 n_hidden_layers = 1, hidden_layer_size = 8, reg_penalty = 0.010000
# 01:50:50 Generate splits [140, 280, 419, 558, 697]
# 01:50:50 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:52:03 Xval MSE 78.391659
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:53:31 Xval MSE 126.096752
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:55:11 Xval MSE 102.202955
# Last Xval loss 102.202955
# Avg Xval loss 102.230455
# --------------------------------------------------------------------------------
# 01:55:12 Running experiment 19 of 60
# 01:55:12 n_hidden_layers = 1, hidden_layer_size = 8, reg_penalty = 0.100000
# 01:55:12 Generate splits [140, 280, 419, 558, 697]
# 01:55:12 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 01:56:31 Xval MSE 102.344461
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 01:58:02 Xval MSE 139.440386
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 01:59:47 Xval MSE 116.915280
# Last Xval loss 116.915280
# Avg Xval loss 119.566709
# --------------------------------------------------------------------------------
# 01:59:47 Running experiment 20 of 60
# 01:59:47 n_hidden_layers = 1, hidden_layer_size = 8, reg_penalty = 1.000000
# 01:59:47 Generate splits [140, 280, 419, 558, 697]
# 01:59:47 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:01:10 Xval MSE 71.978886
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:02:44 Xval MSE 150.852769
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:04:31 Xval MSE 133.710550
# Last Xval loss 133.710550
# Avg Xval loss 118.847401
# --------------------------------------------------------------------------------
# 02:04:31 Running experiment 21 of 60
# 02:04:31 n_hidden_layers = 2, hidden_layer_size = 1, reg_penalty = 0.000000
# 02:04:31 Generate splits [140, 280, 419, 558, 697]
# 02:04:31 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:04:33 Xval MSE 32.686372
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:04:38 Xval MSE 69.045465
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:04:43 Xval MSE 65.713199
# Last Xval loss 65.713199
# Avg Xval loss 55.815012
# --------------------------------------------------------------------------------
# 02:04:43 Running experiment 22 of 60
# 02:04:43 n_hidden_layers = 2, hidden_layer_size = 1, reg_penalty = 0.001000
# 02:04:43 Generate splits [140, 280, 419, 558, 697]
# 02:04:43 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:04:47 Xval MSE 32.547765
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:04:51 Xval MSE 69.338861
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:04:56 Xval MSE 66.001233
# Last Xval loss 66.001233
# Avg Xval loss 55.962620
# --------------------------------------------------------------------------------
# 02:04:56 Running experiment 23 of 60
# 02:04:56 n_hidden_layers = 2, hidden_layer_size = 1, reg_penalty = 0.010000
# 02:04:56 Generate splits [140, 280, 419, 558, 697]
# 02:04:56 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:04:59 Xval MSE 32.688817
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:05:04 Xval MSE 69.118958
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:05:08 Xval MSE 65.005380
# Last Xval loss 65.005380
# Avg Xval loss 55.604385
# --------------------------------------------------------------------------------
# 02:05:08 Running experiment 24 of 60
# 02:05:08 n_hidden_layers = 2, hidden_layer_size = 1, reg_penalty = 0.100000
# 02:05:08 Generate splits [140, 280, 419, 558, 697]
# 02:05:08 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:05:22 Xval MSE 34.482653
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:05:35 Xval MSE 70.190898
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:05:45 Xval MSE 65.758585
# Last Xval loss 65.758585
# Avg Xval loss 56.810712
# --------------------------------------------------------------------------------
# 02:05:45 Running experiment 25 of 60
# 02:05:45 n_hidden_layers = 2, hidden_layer_size = 1, reg_penalty = 1.000000
# 02:05:45 Generate splits [140, 280, 419, 558, 697]
# 02:05:45 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:06:10 Xval MSE 38.549288
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:06:30 Xval MSE 72.898778
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:06:46 Xval MSE 67.255292
# Last Xval loss 67.255292
# Avg Xval loss 59.567786
# --------------------------------------------------------------------------------
# 02:06:46 Running experiment 26 of 60
# 02:06:46 n_hidden_layers = 2, hidden_layer_size = 2, reg_penalty = 0.000000
# 02:06:46 Generate splits [140, 280, 419, 558, 697]
# 02:06:46 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ...................
# 02:08:45 Xval MSE 72.630741
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:09:21 Xval MSE 70.831766
# Last Xval loss 70.831766
# Avg Xval loss 60.395153
# --------------------------------------------------------------------------------
# 02:09:21 Running experiment 28 of 60
# 02:09:21 n_hidden_layers = 2, hidden_layer_size = 2, reg_penalty = 0.010000
# 02:09:21 Generate splits [140, 280, 419, 558, 697]
# 02:09:21 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:09:37 Xval MSE 37.917865
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:10:02 Xval MSE 73.002245
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:10:44 Xval MSE 71.853615
# Last Xval loss 71.853615
# Avg Xval loss 60.924575
# --------------------------------------------------------------------------------
# 02:10:44 Running experiment 29 of 60
# 02:10:44 n_hidden_layers = 2, hidden_layer_size = 2, reg_penalty = 0.100000
# 02:10:44 Generate splits [140, 280, 419, 558, 697]
# 02:10:44 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:11:50 Xval MSE 50.044371
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:13:10 Xval MSE 82.984390
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:14:33 Xval MSE 71.712507
# Last Xval loss 71.712507
# Avg Xval loss 68.247089
# --------------------------------------------------------------------------------
# 02:14:33 Running experiment 30 of 60
# 02:14:33 n_hidden_layers = 2, hidden_layer_size = 2, reg_penalty = 1.000000
# 02:14:33 Generate splits [140, 280, 419, 558, 697]
# 02:14:33 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:15:44 Xval MSE 58.775138
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:17:04 Xval MSE 86.674645
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:18:23 Xval MSE 78.725310
# Last Xval loss 78.725310
# Avg Xval loss 74.725031
# --------------------------------------------------------------------------------
# 02:18:23 Running experiment 31 of 60
# 02:18:23 n_hidden_layers = 2, hidden_layer_size = 4, reg_penalty = 0.000000
# 02:18:23 Generate splits [140, 280, 419, 558, 697]
# 02:18:23 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:19:31 Xval MSE 49.382229
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:21:09 Xval MSE 89.914733
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:22:51 Xval MSE 80.949559
# Last Xval loss 80.949559
# Avg Xval loss 73.415507
# --------------------------------------------------------------------------------
# 02:22:51 Running experiment 32 of 60
# 02:22:51 n_hidden_layers = 2, hidden_layer_size = 4, reg_penalty = 0.001000
# 02:22:51 Generate splits [140, 280, 419, 558, 697]
# 02:22:51 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:23:53 Xval MSE 48.792757
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:25:27 Xval MSE 89.633022
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:27:06 Xval MSE 79.684190
# Last Xval loss 79.684190
# Avg Xval loss 72.703323
# --------------------------------------------------------------------------------
# 02:27:06 Running experiment 33 of 60
# 02:27:06 n_hidden_layers = 2, hidden_layer_size = 4, reg_penalty = 0.010000
# 02:27:06 Generate splits [140, 280, 419, 558, 697]
# 02:27:06 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:28:17 Xval MSE 52.473603
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:29:43 Xval MSE 82.706832
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:31:29 Xval MSE 83.298060
# Last Xval loss 83.298060
# Avg Xval loss 72.826165
# --------------------------------------------------------------------------------
# 02:31:29 Running experiment 34 of 60
# 02:31:29 n_hidden_layers = 2, hidden_layer_size = 4, reg_penalty = 0.100000
# 02:31:29 Generate splits [140, 280, 419, 558, 697]
# 02:31:29 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:32:52 Xval MSE 55.446307
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:34:33 Xval MSE 86.818304
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:36:22 Xval MSE 82.031513
# Last Xval loss 82.031513
# Avg Xval loss 74.765375
# --------------------------------------------------------------------------------
# 02:36:22 Running experiment 35 of 60
# 02:36:22 n_hidden_layers = 2, hidden_layer_size = 4, reg_penalty = 1.000000
# 02:36:22 Generate splits [140, 280, 419, 558, 697]
# 02:36:22 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:37:47 Xval MSE 82.043681
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:39:28 Xval MSE 115.543576
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:41:18 Xval MSE 89.449478
# Last Xval loss 89.449478
# Avg Xval loss 95.678912
# --------------------------------------------------------------------------------
# 02:41:18 Running experiment 36 of 60
# 02:41:18 n_hidden_layers = 2, hidden_layer_size = 8, reg_penalty = 0.000000
# 02:41:18 Generate splits [140, 280, 419, 558, 697]
# 02:41:18 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:43:03 Xval MSE 74.769278
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:45:14 Xval MSE 124.897302
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:47:49 Xval MSE 108.841347
# Last Xval loss 108.841347
# Avg Xval loss 102.835976
# --------------------------------------------------------------------------------
# 02:47:49 Running experiment 37 of 60
# 02:47:49 n_hidden_layers = 2, hidden_layer_size = 8, reg_penalty = 0.001000
# 02:47:49 Generate splits [140, 280, 419, 558, 697]
# 02:47:49 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:49:39 Xval MSE 76.766652
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:51:53 Xval MSE 128.553662
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 02:54:27 Xval MSE 113.497971
# Last Xval loss 113.497971
# Avg Xval loss 106.272761
# --------------------------------------------------------------------------------
# 02:54:27 Running experiment 38 of 60
# 02:54:27 n_hidden_layers = 2, hidden_layer_size = 8, reg_penalty = 0.010000
# 02:54:27 Generate splits [140, 280, 419, 558, 697]
# 02:54:27 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 02:56:14 Xval MSE 76.187737
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 02:58:26 Xval MSE 121.706014
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:00:57 Xval MSE 109.066105
# Last Xval loss 109.066105
# Avg Xval loss 102.319952
# --------------------------------------------------------------------------------
# 03:00:57 Running experiment 39 of 60
# 03:00:57 n_hidden_layers = 2, hidden_layer_size = 8, reg_penalty = 0.100000
# 03:00:57 Generate splits [140, 280, 419, 558, 697]
# 03:00:57 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:02:57 Xval MSE 72.663710
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:05:16 Xval MSE 118.056121
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:07:53 Xval MSE 109.609946
# Last Xval loss 109.609946
# Avg Xval loss 100.109926
# --------------------------------------------------------------------------------
# 03:07:53 Running experiment 40 of 60
# 03:07:53 n_hidden_layers = 2, hidden_layer_size = 8, reg_penalty = 1.000000
# 03:07:53 Generate splits [140, 280, 419, 558, 697]
# 03:07:53 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:09:54 Xval MSE 82.783863
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:12:14 Xval MSE 131.892440
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:15:11 Xval MSE 122.780133
# Last Xval loss 122.780133
# Avg Xval loss 112.485479
# --------------------------------------------------------------------------------
# 03:15:11 Running experiment 41 of 60
# 03:15:11 n_hidden_layers = 3, hidden_layer_size = 1, reg_penalty = 0.000000
# 03:15:11 Generate splits [140, 280, 419, 558, 697]
# 03:15:11 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:15:14 Xval MSE 32.273047
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:15:19 Xval MSE 67.118922
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:15:23 Xval MSE 64.528296
# Last Xval loss 64.528296
# Avg Xval loss 54.640088
# --------------------------------------------------------------------------------
# 03:15:23 Running experiment 42 of 60
# 03:15:23 n_hidden_layers = 3, hidden_layer_size = 1, reg_penalty = 0.001000
# 03:15:23 Generate splits [140, 280, 419, 558, 697]
# 03:15:23 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:15:26 Xval MSE 32.182898
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:15:31 Xval MSE 68.354937
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:15:36 Xval MSE 64.719118
# Last Xval loss 64.719118
# Avg Xval loss 55.085651
# --------------------------------------------------------------------------------
# 03:15:36 Running experiment 43 of 60
# 03:15:36 n_hidden_layers = 3, hidden_layer_size = 1, reg_penalty = 0.010000
# 03:15:36 Generate splits [140, 280, 419, 558, 697]
# 03:15:36 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:15:40 Xval MSE 32.490299
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:15:46 Xval MSE 69.209688
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:15:52 Xval MSE 64.897102
# Last Xval loss 64.897102
# Avg Xval loss 55.532363
# --------------------------------------------------------------------------------
# 03:15:52 Running experiment 44 of 60
# 03:15:52 n_hidden_layers = 3, hidden_layer_size = 1, reg_penalty = 0.100000
# 03:15:52 Generate splits [140, 280, 419, 558, 697]
# 03:15:52 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:16:07 Xval MSE 34.124686
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:16:14 Xval MSE 68.506407
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:16:25 Xval MSE 65.691347
# Last Xval loss 65.691347
# Avg Xval loss 56.107480
# --------------------------------------------------------------------------------
# 03:16:25 Running experiment 45 of 60
# 03:16:25 n_hidden_layers = 3, hidden_layer_size = 1, reg_penalty = 1.000000
# 03:16:25 Generate splits [140, 280, 419, 558, 697]
# 03:16:25 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:17:01 Xval MSE 38.644669
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:17:30 Xval MSE 72.993240
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:17:54 Xval MSE 67.375143
# Last Xval loss 67.375143
# Avg Xval loss 59.671017
# --------------------------------------------------------------------------------
# 03:17:54 Running experiment 46 of 60
# 03:17:54 n_hidden_layers = 3, hidden_layer_size = 2, reg_penalty = 0.000000
# 03:17:54 Generate splits [140, 280, 419, 558, 697]
# 03:17:54 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:18:17 Xval MSE 38.038601
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:18:57 Xval MSE 75.884475
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:20:06 Xval MSE 71.776603
# Last Xval loss 71.776603
# Avg Xval loss 61.899893
# --------------------------------------------------------------------------------
# 03:20:06 Running experiment 47 of 60
# 03:20:06 n_hidden_layers = 3, hidden_layer_size = 2, reg_penalty = 0.001000
# 03:20:06 Generate splits [140, 280, 419, 558, 697]
# 03:20:06 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:20:33 Xval MSE 36.282504
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:21:20 Xval MSE 74.471780
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:22:32 Xval MSE 73.460786
# Last Xval loss 73.460786
# Avg Xval loss 61.405023
# --------------------------------------------------------------------------------
# 03:22:32 Running experiment 48 of 60
# 03:22:32 n_hidden_layers = 3, hidden_layer_size = 2, reg_penalty = 0.010000
# 03:22:32 Generate splits [140, 280, 419, 558, 697]
# 03:22:32 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:23:02 Xval MSE 37.003012
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:23:43 Xval MSE 73.370542
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:24:49 Xval MSE 75.643023
# Last Xval loss 75.643023
# Avg Xval loss 62.005526
# --------------------------------------------------------------------------------
# 03:24:49 Running experiment 49 of 60
# 03:24:49 n_hidden_layers = 3, hidden_layer_size = 2, reg_penalty = 0.100000
# 03:24:49 Generate splits [140, 280, 419, 558, 697]
# 03:24:49 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:26:03 Xval MSE 47.779902
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:27:40 Xval MSE 76.436665
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:29:25 Xval MSE 72.659907
# Last Xval loss 72.659907
# Avg Xval loss 65.625492
# --------------------------------------------------------------------------------
# 03:29:25 Running experiment 50 of 60
# 03:29:25 n_hidden_layers = 3, hidden_layer_size = 2, reg_penalty = 1.000000
# 03:29:25 Generate splits [140, 280, 419, 558, 697]
# 03:29:25 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:30:51 Xval MSE 59.114034
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:32:35 Xval MSE 87.864638
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:34:29 Xval MSE 74.007866
# Last Xval loss 74.007866
# Avg Xval loss 73.662179
# --------------------------------------------------------------------------------
# 03:34:29 Running experiment 51 of 60
# 03:34:29 n_hidden_layers = 3, hidden_layer_size = 4, reg_penalty = 0.000000
# 03:34:29 Generate splits [140, 280, 419, 558, 697]
# 03:34:29 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:35:57 Xval MSE 51.264903
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:37:51 Xval MSE 86.534377
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:40:05 Xval MSE 89.627341
# Last Xval loss 89.627341
# Avg Xval loss 75.808874
# --------------------------------------------------------------------------------
# 03:40:05 Running experiment 52 of 60
# 03:40:05 n_hidden_layers = 3, hidden_layer_size = 4, reg_penalty = 0.001000
# 03:40:05 Generate splits [140, 280, 419, 558, 697]
# 03:40:05 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:41:32 Xval MSE 49.395727
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:43:26 Xval MSE 90.911096
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:45:40 Xval MSE 85.416052
# Last Xval loss 85.416052
# Avg Xval loss 75.240958
# --------------------------------------------------------------------------------
# 03:45:40 Running experiment 53 of 60
# 03:45:40 n_hidden_layers = 3, hidden_layer_size = 4, reg_penalty = 0.010000
# 03:45:40 Generate splits [140, 280, 419, 558, 697]
# 03:45:40 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# .........................
# 03:49:11 Xval MSE 92.362554
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:51:28 Xval MSE 81.982551
# Last Xval loss 81.982551
# Avg Xval loss 74.983741
# --------------------------------------------------------------------------------
# 03:51:28 Running experiment 54 of 60
# 03:51:28 n_hidden_layers = 3, hidden_layer_size = 4, reg_penalty = 0.100000
# 03:51:28 Generate splits [140, 280, 419, 558, 697]
# 03:51:28 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:53:12 Xval MSE 55.749131
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 03:55:21 Xval MSE 84.225493
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 03:57:39 Xval MSE 85.033597
# Last Xval loss 85.033597
# Avg Xval loss 75.002740
# --------------------------------------------------------------------------------
# 03:57:39 Running experiment 55 of 60
# 03:57:39 n_hidden_layers = 3, hidden_layer_size = 4, reg_penalty = 1.000000
# 03:57:39 Generate splits [140, 280, 419, 558, 697]
# 03:57:39 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 03:59:24 Xval MSE 76.938521
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 04:01:27 Xval MSE 106.459058
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 04:03:46 Xval MSE 93.899161
# Last Xval loss 93.899161
# Avg Xval loss 92.432247
# --------------------------------------------------------------------------------
# 04:03:46 Running experiment 56 of 60
# 04:03:46 n_hidden_layers = 3, hidden_layer_size = 8, reg_penalty = 0.000000
# 04:03:46 Generate splits [140, 280, 419, 558, 697]
# 04:03:46 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 04:06:04 Xval MSE 73.311056
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 04:08:56 Xval MSE 124.075090
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 04:12:17 Xval MSE 109.363502
# Last Xval loss 109.363502
# Avg Xval loss 102.249883
# --------------------------------------------------------------------------------
# 04:12:17 Running experiment 57 of 60
# 04:12:17 n_hidden_layers = 3, hidden_layer_size = 8, reg_penalty = 0.001000
# 04:12:17 Generate splits [140, 280, 419, 558, 697]
# 04:12:17 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 04:14:34 Xval MSE 68.549480
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 04:17:26 Xval MSE 119.257299
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 04:20:52 Xval MSE 117.216573
# Last Xval loss 117.216573
# Avg Xval loss 101.674451
# --------------------------------------------------------------------------------
# 04:20:52 Running experiment 58 of 60
# 04:20:52 n_hidden_layers = 3, hidden_layer_size = 8, reg_penalty = 0.010000
# 04:20:52 Generate splits [140, 280, 419, 558, 697]
# 04:20:52 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 04:23:13 Xval MSE 70.115583
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 04:26:07 Xval MSE 114.242539
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 04:29:34 Xval MSE 106.136286
# Last Xval loss 106.136286
# Avg Xval loss 96.831469
# --------------------------------------------------------------------------------
# 04:29:34 Running experiment 59 of 60
# 04:29:34 n_hidden_layers = 3, hidden_layer_size = 8, reg_penalty = 0.100000
# 04:29:34 Generate splits [140, 280, 419, 558, 697]
# 04:29:34 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 04:31:54 Xval MSE 75.349440
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 04:34:49 Xval MSE 119.513582
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# .................
# 04:38:13 Xval MSE 113.150904
# Last Xval loss 113.150904
# Avg Xval loss 102.671309
# --------------------------------------------------------------------------------
# 04:38:13 Running experiment 60 of 60
# 04:38:13 n_hidden_layers = 3, hidden_layer_size = 8, reg_penalty = 1.000000
# 04:38:13 Generate splits [140, 280, 419, 558, 697]
# 04:38:13 Starting training
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# ..............................
# 04:40:39 Xval MSE 99.107887
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
# ..............................
# 04:43:37 Xval MSE 128.849316
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# ..............................
# 04:47:08 Xval MSE 121.684946
# Last Xval loss 121.684946
# Avg Xval loss 116.547383
# --------------------------------------------------------------------------------

# %%
# list and chart experiments
flatlist = [list(l[0]) + [l[1]] for l in experiments.items()]
 
lossframe = pd.DataFrame(flatlist, columns=["n_hidden_layers", "layer_size", "reg_penalty", "loss"])
lossframe.sort_values(['loss'])
# Out:
#     n_hidden_layers  layer_size  reg_penalty        loss
# 38                3           1        0.000   54.640088
# 31                3           1        0.001   55.085651
# 43                3           1        0.010   55.532363
# 56                2           1        0.010   55.604385
# 49                2           1        0.000   55.815012
# 50                2           1        0.001   55.962620
# 0                 3           1        0.100   56.107480
# 55                1           1        0.001   56.327276
# 47                1           1        0.000   56.802747
# 15                2           1        0.100   56.810712
# 34                1           1        0.010   57.030138
# 52                1           1        0.100   58.617741
# 1                 2           1        1.000   59.567786
# 35                3           1        1.000   59.671017
# 44                1           1        1.000   60.221951
# 48                2           2        0.001   60.395153
# 54                2           2        0.000   60.406276
# 29                2           2        0.010   60.924575
# 27                3           2        0.001   61.405023
# 32                3           2        0.000   61.899893
# 6                 1           2        0.001   61.961284
# 10                3           2        0.010   62.005526
# 14                1           2        0.010   62.251068
# 30                1           2        0.000   63.454295
# 53                3           2        0.100   65.625492
# 45                2           2        0.100   68.247089
# 26                2           4        0.001   72.703323
# 8                 2           4        0.010   72.826165
# 19                1           4        0.000   73.235608
# 18                2           4        0.000   73.415507
# 36                3           2        1.000   73.662179
# 20                1           4        0.001   74.532575
# 51                2           2        1.000   74.725031
# 46                2           4        0.100   74.765375
# 37                3           4        0.010   74.983741
# 17                3           4        0.100   75.002740
# 13                3           4        0.001   75.240958
# 40                3           4        0.000   75.808874
# 28                1           4        0.010   78.758035
# 2                 1           2        0.100   79.207253
# 33                1           2        1.000   83.606619
# 9                 3           4        1.000   92.432247
# 7                 2           4        1.000   95.678912
# 24                3           8        0.010   96.831469
# 39                1           8        0.000   97.151074
# 5                 1           8        0.001   99.206606
# 25                2           8        0.100  100.109926
# 12                1           4        0.100  101.265660
# 41                3           8        0.001  101.674451
# 4                 1           8        0.010  102.230455
# 22                3           8        0.000  102.249883
# 16                2           8        0.010  102.319952
# 57                3           8        0.100  102.671309
# 3                 2           8        0.000  102.835976
# 11                2           8        0.001  106.272761
# 58                2           8        1.000  112.485479
# 23                1           4        1.000  113.014015
# 21                3           8        1.000  116.547383
# 42                1           8        1.000  118.847401
# 59                1           8        0.100  119.566709

# %%
# we can pick lowest loss , but first we look at patterns by hyperparameter
pd.DataFrame(lossframe.groupby(['n_hidden_layers'])['loss'].mean())
# Out:
#                       loss
# n_hidden_layers
# 1                80.864425
# 2                76.093601
# 3                75.953888

# %%
pd.DataFrame(lossframe.groupby(['layer_size'])['loss'].mean())
# Out:
#                   loss
# layer_size
# 1            56.919798
# 2            66.651784
# 4            81.577582
# 8           105.400056

# %%
pd.DataFrame(lossframe.groupby(['reg_penalty'])['loss'].mean())
# Out:
#                   loss
# reg_penalty
# 0.000        73.142936
# 0.001        73.397307
# 0.010        73.441489
# 0.100        79.833124
# 1.000        88.371668

# %%
def plot_matrix(lossframe, x_labels, y_labels, x_suffix="", y_suffix=""):

    pivot = lossframe.pivot_table(index=[y_labels], columns=[x_labels], values=['loss'])
#    print(pivot)
    # specify labels as strings, to force plotly to use a discrete axis
#    print(pivot.columns.levels[1]).values
#    print(lossframe[x_labels].dtype)
    
    if lossframe[x_labels].dtype == np.float64 or lossframe[x_labels].dtype == np.float32:
        xaxis = ["%f %s" % (i, x_suffix) for i in pivot.columns.levels[1].values]
    else:
        xaxis = ["%d %s" % (i, x_suffix) for i in pivot.columns.levels[1].values]
    if lossframe[y_labels].dtype == np.float64 or lossframe[y_labels].dtype == np.float32:
        yaxis = ["%f %s" % (i, y_suffix) for i in pivot.index.values]
    else:
        yaxis = ["%d %s" % (i, y_suffix) for i in pivot.index.values]
        
#    print(xaxis, yaxis)
    """plot a heat map of a matrix"""
    chart_width=640
    chart_height=480
    
    layout = Layout(
        title="%s v. %s" % (x_labels, y_labels),
        height=chart_height,
        width=chart_width,     
        margin=dict(
            l=150,
            r=30,
            b=120,
            t=100,
        ),
        xaxis=dict(
            title=x_labels,
            tickfont=dict(
                family='Arial, sans-serif',
                size=10,
                color='black'
            ),
        ),
        yaxis=dict(
            title=y_labels,
            tickfont=dict(
                family='Arial, sans-serif',
                size=10,
                color='black'
            ),
        ),
    )
    
    data = [Heatmap(z=pivot.values,
                    x=xaxis,
                    y=yaxis,
                    colorscale=[[0, 'rgb(0,0,255)', [1, 'rgb(255,0,0)']]],
                   )
           ]

    fig = Figure(data=data, layout=layout)
    return iplot(fig, link_text="")

plot_matrix(lossframe, "n_hidden_layers", "layer_size", x_suffix=" layers", y_suffix=" units")
# Out:
# <div id="abafd2a8-1514-402b-83c9-154650269766" style="height: 480px; width: 640px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("abafd2a8-1514-402b-83c9-154650269766", [{"y": ["1  units", "2  units", "4  units", "8  units"], "x": ["1  layers", "2  layers", "3  layers"], "z": [[57.799970499881866, 56.75210298298856, 56.2073198521105], [70.09610388663273, 64.93962495197601, 64.91962255338277], [88.16117852185184, 77.87785618365928, 78.69371219026529], [107.4004490334396, 104.80481869825982, 103.99489887736722]], "type": "heatmap", "colorscale": [[0, "rgb(0,0,255)", [1, "rgb(255,0,0)"]]]}], {"title": "n_hidden_layers v. layer_size", "yaxis": {"tickfont": {"color": "black", "family": "Arial, sans-serif", "size": 10}, "title": "layer_size"}, "height": 480, "width": 640, "xaxis": {"tickfont": {"color": "black", "family": "Arial, sans-serif", "size": 10}, "title": "n_hidden_layers"}, "margin": {"r": 30, "b": 120, "t": 100, "l": 150}}, {"linkText": "", "showLink": true})});</script>

# %%
plot_matrix(lossframe, "n_hidden_layers", "reg_penalty", x_suffix=" layers", y_suffix=" rp")
# Out:
# <div id="b3a8f67e-ac6f-4082-b95c-f0f4e3a58975" style="height: 480px; width: 640px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b3a8f67e-ac6f-4082-b95c-f0f4e3a58975", [{"y": ["0.000000  rp", "0.001000  rp", "0.010000  rp", "0.100000  rp", "1.000000  rp"], "x": ["1  layers", "2  layers", "3  layers"], "z": [[72.66093097016294, 73.11819262008353, 73.6496843600186], [73.00693520650348, 73.83346428203785, 73.35152102754532], [75.06742396571528, 72.91876934923354, 72.33827475892508], [89.6643408060362, 74.98327543721693, 74.85175510731437], [93.92249647883965, 85.61430183253276, 85.57820658760387]], "type": "heatmap", "colorscale": [[0, "rgb(0,0,255)", [1, "rgb(255,0,0)"]]]}], {"title": "n_hidden_layers v. reg_penalty", "yaxis": {"tickfont": {"color": "black", "family": "Arial, sans-serif", "size": 10}, "title": "reg_penalty"}, "height": 480, "width": 640, "xaxis": {"tickfont": {"color": "black", "family": "Arial, sans-serif", "size": 10}, "title": "n_hidden_layers"}, "margin": {"r": 30, "b": 120, "t": 100, "l": 150}}, {"linkText": "", "showLink": true})});</script>

# %%
plot_matrix(lossframe, "layer_size", "reg_penalty", x_suffix=" units", y_suffix=" rp")
# Out:
# <div id="3b2e80d5-6f9a-4a80-9bae-2645ca311769" style="height: 480px; width: 640px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3b2e80d5-6f9a-4a80-9bae-2645ca311769", [{"y": ["0.000000  rp", "0.001000  rp", "0.010000  rp", "0.100000  rp", "1.000000  rp"], "x": ["1  units", "2  units", "4  units", "8  units"], "z": [[55.752615800248996, 61.92015459058289, 74.15332946707373, 100.74564407578112], [55.7918491586938, 61.2538202246296, 74.15895198515919, 102.38460598629962], [56.05562855186442, 61.72705623948345, 75.5226471532951, 100.4606254871889], [57.178644169668424, 71.02661141440933, 83.67792509433916, 107.44931445567308], [59.820251211159274, 77.33127651754727, 100.37505779309349, 115.96008767683499]], "type": "heatmap", "colorscale": [[0, "rgb(0,0,255)", [1, "rgb(255,0,0)"]]]}], {"title": "layer_size v. reg_penalty", "yaxis": {"tickfont": {"color": "black", "family": "Arial, sans-serif", "size": 10}, "title": "reg_penalty"}, "height": 480, "width": 640, "xaxis": {"tickfont": {"color": "black", "family": "Arial, sans-serif", "size": 10}, "title": "layer_size"}, "margin": {"r": 30, "b": 120, "t": 100, "l": 150}}, {"linkText": "", "showLink": true})});</script>

# %%
# these results are not very good, ~same as LinearRegression, but try best one
# 1-unit layers is not really a NN but anyway let's see how it does

run_backtest(X, Y, create_model(3, 1, 0.0), 
             coef_dict='all', 
             initial_train_months=FIRST_TRAIN_MONTHS)

# slightly worse OOS MSE than linear regression (45.2) but much worse Sharpe
# Out:
# ................................................................................
# 10:02:02 Still training 80 of 577
# ................................................................................
# 10:05:59 Still training 160 of 577
# ................................................................................
# 10:10:25 Still training 240 of 577
# ................................................................................
# 10:16:10 Still training 320 of 577
# ................................................................................
# 10:22:12 Still training 400 of 577
# ................................................................................
# 10:28:23 Still training 480 of 577
# ................................................................................
# 10:34:42 Still training 560 of 577
# ................
# MSE across all predictions: 41.2533
# Variance: 39.5535
# R-squared: -0.0430

# %%
gen_returns(X, P, FIRST_PREDICT_MONTH, verbose=False)
# Out:
# Food.lead: long 107 times, short 70 times, total 177 times
# Beer.lead: long 128 times, short 97 times, total 225 times
# Smoke.lead: long 193 times, short 83 times, total 276 times
# Games.lead: long 199 times, short 154 times, total 353 times
# Books.lead: long 126 times, short 116 times, total 242 times
# Hshld.lead: long 77 times, short 99 times, total 176 times
# Clths.lead: long 162 times, short 155 times, total 317 times
# Hlth.lead: long 107 times, short 78 times, total 185 times
# Chems.lead: long 50 times, short 128 times, total 178 times
# Txtls.lead: long 146 times, short 116 times, total 262 times
# Cnstr.lead: long 85 times, short 108 times, total 193 times
# Steel.lead: long 69 times, short 189 times, total 258 times
# FabPr.lead: long 55 times, short 108 times, total 163 times
# ElcEq.lead: long 122 times, short 85 times, total 207 times
# Autos.lead: long 77 times, short 148 times, total 225 times
# Carry.lead: long 114 times, short 136 times, total 250 times
# Mines.lead: long 149 times, short 117 times, total 266 times
# Coal.lead: long 213 times, short 151 times, total 364 times
# Oil.lead: long 85 times, short 83 times, total 168 times
# Util.lead: long 58 times, short 120 times, total 178 times
# Telcm.lead: long 81 times, short 105 times, total 186 times
# Servs.lead: long 144 times, short 105 times, total 249 times
# BusEq.lead: long 86 times, short 116 times, total 202 times
# Paper.lead: long 77 times, short 108 times, total 185 times
# Trans.lead: long 108 times, short 116 times, total 224 times
# Whlsl.lead: long 128 times, short 96 times, total 224 times
# Rtail.lead: long 118 times, short 103 times, total 221 times
# Meals.lead: long 197 times, short 126 times, total 323 times
# Fin.lead: long 95 times, short 104 times, total 199 times
# Other.lead: long 94 times, short 130 times, total 224 times
#                              Value
# start          1970-01-31 00:00:00
# end            2017-12-31 00:00:00
# cagr                     0.0126664
# yearly_vol               0.0448401
# yearly_sharpe             0.335211
# max_drawdown             -0.129298
# sortino                   0.135873

# %%
# try keras instead of sklearn MLPRegressor
# wrap their model in a class 
# we are using multioutput to speed things up 
# fit takes a list of response ys, predict returns a list of y_predict arrays
INPUT_DIM = X.shape[1]
print(INPUT_DIM)
OUTPUT_DIM = len(responses) # 30
BATCH_SIZE = 32
EPOCHS=80

class KerasBacktestModel(object):

    def __init__(self, 
                 n_hidden_layers = 2,
                 hidden_layer_size = 32,
                 reg_penalty = 0.0001,
                 dropout = 0.333,
                 verbose=True):
        main_input = Input(shape=(INPUT_DIM,),
                           dtype='float32', 
                           name='main_input')
        lastlayer=main_input
        
        for i in range(n_hidden_layers):
            if verbose:
                print("layer %d size %d, reg_penalty %.8f, dropout %.3f" % (i + 1, 
                                                                            hidden_layer_size, 
                                                                            reg_penalty, 
                                                                            dropout))
            lastlayer = Dense(units = hidden_layer_size, 
                              activation = 'relu',
                              kernel_initializer = keras.initializers.glorot_uniform(),
                              kernel_regularizer=keras.regularizers.l1(reg_penalty),
                              name = "Dense%02d" % i)(lastlayer)
            
            if dropout:
                lastlayer = Dropout(dropout, name = "Dropout%02d" % i)(lastlayer)
                
        outputs = []
        for i in range(OUTPUT_DIM):
            # OUTPUT_DIM outputs
            output = Dense(1,
                           activation='linear',
                           name='output%02d' % i)(lastlayer)
            outputs.append(output)
            
        self.model = Model(inputs=[main_input], outputs=outputs)
        if verbose:
            print(self.model.summary())
            
        self.model.compile(loss="mse", optimizer="rmsprop", loss_weights=[1.]*OUTPUT_DIM)
        
    def fit(self, X, Y, epochs=EPOCHS):
        # convert Y to list of ys
        Y_list = [Y[:,i] for i in range(OUTPUT_DIM)]
        return self.model.fit(X,
                              Y_list,
                              batch_size=BATCH_SIZE,
                              epochs=epochs,
                              verbose=False)
    
    def predict(self, X):
        # convert list of ys to Y array
        y_list = self.model.predict(X)
        npreds=len(y_list[0])
        Y_xval_pred = [y.reshape(npreds) for y in y_list]
        Y_xval_pred = np.array(Y_xval_pred).transpose()    
        return Y_xval_pred
    
    def save(self, modelname):
        self.model.save("%s.h5" % modelname)
        self.model.save_weights("%s_weights.h5" % modelname)
# Out:
# 103

# %%
def create_keras_model(n_hidden_layers, layer_size, reg_penalty, dropout, verbose=False):
    def create_func():
        return KerasBacktestModel(n_hidden_layers = n_hidden_layers,
                                  hidden_layer_size = layer_size,
                                  reg_penalty = reg_penalty,
                                  dropout = dropout,
                                  verbose=verbose)
    return create_func

# %%
def fit_predict_keras(X, Y, model, epochs=EPOCHS, npredict=1, verbose=False):
    """simpler fit_predict, no coef_dict, fits all at once, specifies epochs 
    for backtest, train model using Y_list v. X using n-npredict rows
    generate npredict prediction Y_list using last npredict rows of X
    if npredict=1, fit using n-1 rows, return prediction using X for final month
    if npredict=26, fit using n-26 rows, return prediction using X for final 26 months"""
    
    nrows = X.shape[0]
    if verbose:
        print("Fit on %d rows 0 to %d" % (nrows-npredict, nrows-npredict-1))
        print("Predict on %d rows %d to %d" % (npredict, nrows-npredict, nrows-1))
        
    # keep last rows to predict against
    X_predict = X[-npredict:]
    X_predict = X_predict.reshape(npredict,X.shape[1])
    # fit on remaining rows
    X_fit = X[:-npredict]
    Y_fit = Y[:-npredict]
    
    fit = model.fit(
        X_fit,
        Y_fit,
        epochs=epochs
    )
    
    return model.predict(X_predict)

print("%s Start fit" % (time.strftime("%H:%M:%S")))
keras_create_model=create_keras_model(1, 4, 0.01, 0.25)
keras_model=keras_create_model(verbose=True)
predictions = fit_predict_keras(X, Y, keras_model, npredict=3, epochs=3)
print("%s End fit" % (time.strftime("%H:%M:%S")))

predictions
# Out:
# 11:39:28 Start fit
# layer 1 size 4, reg_penalty 0.01000000, dropout 0.250
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 103)          0
# __________________________________________________________________________________________________
# Dense00 (Dense)                 (None, 4)            416         main_input[0][0]
# __________________________________________________________________________________________________
# Dropout00 (Dropout)             (None, 4)            0           Dense00[0][0]
# __________________________________________________________________________________________________
# output00 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output01 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output02 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output03 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output04 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output05 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output06 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output07 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output08 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output09 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output10 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output11 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output12 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output13 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output14 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output15 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output16 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output17 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output18 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output19 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output20 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output21 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output22 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output23 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output24 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output25 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output26 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output27 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output28 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output29 (Dense)                (None, 1)            5           Dropout00[0][0]
# ==================================================================================================
# Total params: 566
# Trainable params: 566
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 11:39:36 End fit
# array([[ 3.0632823 , -0.14469436,  3.5400436 , -1.1777619 ,  0.7302627 ,
#          0.20733154,  0.48030537, -2.8965492 ,  1.1980777 , -1.3838048 ,
#          0.74006546,  0.9542984 ,  0.53694916,  3.2810624 , -0.40520313,
#          3.1337516 , -1.0691235 , -0.15243937,  0.67836004,  0.23011701,
#         -1.0680192 ,  0.54767406, -1.6263189 ,  0.79566485, -1.1569383 ,
#          2.5313826 , -1.0813317 , -1.924275  , -3.1329238 , -0.55992997],
#        [ 1.2874429 ,  0.7980152 ,  1.4525441 , -0.5404324 , -0.2224832 ,
#          0.3672167 ,  0.11850676, -1.2202029 ,  0.7758051 , -1.3226769 ,
#          1.0245316 , -0.31393254, -0.218428  ,  1.347803  ,  0.32448357,
#          1.2431568 , -0.37896353, -0.7740058 , -0.3068104 ,  0.84744513,
#         -0.2652901 ,  1.0738955 , -0.7275055 , -0.09550111, -1.3010827 ,
#          1.031365  , -0.3155843 , -0.96316755, -1.1537324 ,  0.13930702],
#        [-0.6188089 , -0.5800356 , -0.6243864 ,  0.99458295,  0.62529397,
#         -0.5757832 , -0.8252713 ,  0.07836729, -0.9463088 , -0.13678482,
#         -0.72181416,  1.1575512 ,  0.58819145, -0.40763375, -0.03375808,
#         -0.39209923, -0.853227  , -0.75542307,  0.1682631 ,  0.15003474,
#         -0.02841925, -1.0295912 , -0.61047524,  0.60257477, -0.13880119,
#         -0.6223772 ,  0.65703195, -0.39036924, -0.02239868, -0.7171892 ]],
#       dtype=float32)

# %%
EPOCHS=500
def walkforward_xval_keras (X, Y, create_model, n_splits=5, epochs=EPOCHS):
    ### no coef_dict, fit all at once

    # generate k-folds
    kf = KFold(n_splits=n_splits)
    kf.get_n_splits(X)
    last_indexes = []
    for train_index, test_index in kf.split(X):
        # use test_index as last index to train
        last_index = test_index[-1] + 1
        last_indexes.append(last_index)
    print("%s Generate splits %s" % (time.strftime("%H:%M:%S"), str([i for i in last_indexes])))

    print("%s Starting training" % (time.strftime("%H:%M:%S")))
    model = create_model()
    
    avg_bests = []
    for i in range(1, n_splits-1):

        models = []
        losses = []
        scores = []
        count = 0        
        # skip kfold 0 so you start with train 2x size of eval set
        last_train_index = last_indexes[i]
        last_xval_index = last_indexes[i+1]

        # set up train, xval
        # train from beginning to last_train_index        
        print("Training indexes 0 to %d" % (last_train_index-1))
        X_fit = X[:last_train_index]
        Y_fit = Y[:last_train_index]
        
        # xval from last_train_index to last_xval_index
        print("Cross-validating indexes %d to %d" % (last_train_index, last_xval_index -1 ))
        X_xval = X[last_train_index:last_xval_index]
        Y_xval = Y[last_train_index:last_xval_index]

        fit = model.fit(X_fit, Y_fit, epochs=epochs)
        # evaluate ... run prediction, calc MSE by industry, and average
        Y_xval_pred = model.predict(X_xval)
        
        mse_list = [mean_squared_error(Y_xval[:,i], Y_xval_pred[:,i]) for i in range(OUTPUT_DIM)]
        xval_score = np.mean(np.array(mse_list))            

        print ("\n%s Xval MSE %f" % (time.strftime("%H:%M:%S"), xval_score))
        avg_bests.append(xval_score)
    
    # mean over folds
    avg_loss = np.mean(np.array(avg_bests))
    print ("%s Avg Xval loss %f" % (time.strftime("%H:%M:%S"), avg_loss))
    print("--------------------------------------------------------------------------------")
    return (avg_loss, model)

# %%
walkforward_xval_keras(X, Y, 
                       create_keras_model(n_hidden_layers=3,
                                          layer_size=2,
                                          reg_penalty=0.001,
                                          dropout=0.25),
                      epochs=5)
# Out:
# 11:44:45 Generate splits [140, 280, 419, 558, 697]
# 11:44:45 Starting training
# layer 1 size 2, reg_penalty 0.00100000, dropout 0.250
# layer 2 size 2, reg_penalty 0.00100000, dropout 0.250
# layer 3 size 2, reg_penalty 0.00100000, dropout 0.250
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 103)          0
# __________________________________________________________________________________________________
# Dense00 (Dense)                 (None, 2)            208         main_input[0][0]
# __________________________________________________________________________________________________
# Dropout00 (Dropout)             (None, 2)            0           Dense00[0][0]
# __________________________________________________________________________________________________
# Dense01 (Dense)                 (None, 2)            6           Dropout00[0][0]
# __________________________________________________________________________________________________
# Dropout01 (Dropout)             (None, 2)            0           Dense01[0][0]
# __________________________________________________________________________________________________
# Dense02 (Dense)                 (None, 2)            6           Dropout01[0][0]
# __________________________________________________________________________________________________
# Dropout02 (Dropout)             (None, 2)            0           Dense02[0][0]
# __________________________________________________________________________________________________
# output00 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output01 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output02 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output03 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output04 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output05 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output06 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output07 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output08 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output09 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output10 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output11 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output12 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output13 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output14 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output15 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output16 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output17 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output18 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output19 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output20 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output21 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output22 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output23 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output24 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output25 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output26 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output27 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output28 (Dense)                (None, 1)            3           Dropout02[0][0]
# __________________________________________________________________________________________________
# output29 (Dense)                (None, 1)            3           Dropout02[0][0]
# ==================================================================================================
# Total params: 310
# Trainable params: 310
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
#
# 11:44:53 Xval MSE 35.360958
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
#
# 11:44:58 Xval MSE 44.714831
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# 11:45:04 Xval MSE 42.516294
# 11:45:04 Avg Xval loss 40.864027
# --------------------------------------------------------------------------------
# (40.86402743810781, <__main__.KerasBacktestModel at 0x7f3593b1c210>)

# %%
# run an experiment with walk-forward cross-validation

EPOCHS = 50

def run_experiment(X, Y, 
                   n_hidden_layers, 
                   layer_size, 
                   reg_penalty,
                   dropout,
                   minmaxscale=False, 
                   standardscale=False,
                   epochs=EPOCHS):
    
    Xscale = X.copy()
    Yscale = Y.copy()
    
    if minmaxscale:
        # minmaxscale each row (min->0, max->1) - transpose, scale, transpose back because scales by columns
        Xscale = MinMaxScaler().fit_transform(Xscale.transpose()).transpose()
        Yscale = MinMaxScaler().fit_transform(Yscale.transpose()).transpose()
        print("using MinMaxScaler")
    elif standardscale:
        # standardize each row (mean->0, SD->1)- transpose, scale, transpose back because scales by columns
        Xscale = StandardScaler().fit_transform(Xscale.transpose()).transpose()
        Yscale = StandardScaler().fit_transform(Yscale.transpose()).transpose()
        print("using StandardScaler")

    return walkforward_xval_keras(Xscale, Yscale,
                                  create_keras_model(n_hidden_layers=n_hidden_layers,
                                                     layer_size=layer_size,
                                                     reg_penalty=reg_penalty,
                                                     dropout=dropout),
                                  epochs=epochs)

# %%
run_experiment(X, Y, 3, 4, .001, .25, epochs=40)
# Out:
# 11:49:44 Generate splits [140, 280, 419, 558, 697]
# 11:49:44 Starting training
# layer 1 size 4, reg_penalty 0.00100000, dropout 0.250
# layer 2 size 4, reg_penalty 0.00100000, dropout 0.250
# layer 3 size 4, reg_penalty 0.00100000, dropout 0.250
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 103)          0
# __________________________________________________________________________________________________
# Dense00 (Dense)                 (None, 4)            416         main_input[0][0]
# __________________________________________________________________________________________________
# Dropout00 (Dropout)             (None, 4)            0           Dense00[0][0]
# __________________________________________________________________________________________________
# Dense01 (Dense)                 (None, 4)            20          Dropout00[0][0]
# __________________________________________________________________________________________________
# Dropout01 (Dropout)             (None, 4)            0           Dense01[0][0]
# __________________________________________________________________________________________________
# Dense02 (Dense)                 (None, 4)            20          Dropout01[0][0]
# __________________________________________________________________________________________________
# Dropout02 (Dropout)             (None, 4)            0           Dense02[0][0]
# __________________________________________________________________________________________________
# output00 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output01 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output02 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output03 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output04 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output05 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output06 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output07 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output08 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output09 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output10 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output11 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output12 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output13 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output14 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output15 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output16 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output17 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output18 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output19 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output20 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output21 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output22 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output23 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output24 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output25 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output26 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output27 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output28 (Dense)                (None, 1)            5           Dropout02[0][0]
# __________________________________________________________________________________________________
# output29 (Dense)                (None, 1)            5           Dropout02[0][0]
# ==================================================================================================
# Total params: 606
# Trainable params: 606
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
#
# 11:50:15 Xval MSE 32.957050
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
#
# 11:50:53 Xval MSE 40.637947
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
# 11:51:42 Xval MSE 41.112351
# 11:51:42 Avg Xval loss 38.235783
# --------------------------------------------------------------------------------
# (38.235782872409786, <__main__.KerasBacktestModel at 0x7f358a73b950>)

# %%
# improvement in MSE vs. LinearRegression (40ish vs. 54)
# run a lot of experiments in big xval loop to pick best hyperparameters

MODELPREFIX = "FFNN"
EPOCHS=200

n_hiddens = [1, 2, 3]
layer_sizes = [2, 4, 8]
reg_penalties = [0.0, 0.0001, 0.001, 0.01]
dropouts = [0.25]

hyperparameter_combos = list(product(n_hiddens, layer_sizes, reg_penalties, dropouts))

print("%s Running %d experiments" % (time.strftime("%H:%M:%S"), len(hyperparameter_combos)))

experiments = {}

for counter, param_list in enumerate(hyperparameter_combos):
    n_hidden_layers, layer_size, reg_penalty, dropout = param_list
    print("%s Running experiment %d of %d" % (time.strftime("%H:%M:%S"), counter+1, len(hyperparameter_combos)))
    key = (n_hidden_layers, layer_size, reg_penalty, dropout)
    score, model = run_experiment(X, Y,
                                  n_hidden_layers = n_hidden_layers,
                                  layer_size = layer_size,
                                  reg_penalty = reg_penalty,
                                  dropout = dropout,
                                  epochs=EPOCHS
                                 )
    experiments[key] = score 
    modelname = "%s_%.6f_%d_%d_%.6f_%.3f" % (MODELPREFIX, score, n_hidden_layers, layer_size, reg_penalty, dropout)
    print("%s Saving %s.h5" % (time.strftime("%H:%M:%S"), modelname))
    model.save(modelname)
# Out:
# 12:35:07 Running 36 experiments
# 12:35:07 Running experiment 1 of 36
# 12:35:07 Generate splits [140, 280, 419, 558, 697]
# 12:35:07 Starting training
# layer 1 size 2, reg_penalty 0.00000000, dropout 0.250
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 103)          0
# __________________________________________________________________________________________________
# Dense00 (Dense)                 (None, 2)            208         main_input[0][0]
# __________________________________________________________________________________________________
# Dropout00 (Dropout)             (None, 2)            0           Dense00[0][0]
# __________________________________________________________________________________________________
# output00 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output01 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output02 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output03 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output04 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output05 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output06 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output07 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output08 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output09 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output10 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output11 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output12 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output13 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output14 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output15 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output16 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output17 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output18 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output19 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output20 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output21 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output22 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output23 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output24 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output25 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output26 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output27 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output28 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output29 (Dense)                (None, 1)            3           Dropout00[0][0]
# ==================================================================================================
# Total params: 298
# Trainable params: 298
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
#
# 12:37:13 Xval MSE 31.925756
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
#
# 12:40:18 Xval MSE 53.192903
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
#
# 12:44:17 Xval MSE 44.636684
# 12:44:17 Avg Xval loss 43.251781
# --------------------------------------------------------------------------------
# 12:44:17 Saving FFNN_43.251781_1_2_0.000000_0.250.h5
# 12:44:27 Running experiment 2 of 36
# 12:44:27 Generate splits [140, 280, 419, 558, 697]
# 12:44:27 Starting training
# layer 1 size 2, reg_penalty 0.00010000, dropout 0.250
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 103)          0
# __________________________________________________________________________________________________
# Dense00 (Dense)                 (None, 2)            208         main_input[0][0]
# __________________________________________________________________________________________________
# Dropout00 (Dropout)             (None, 2)            0           Dense00[0][0]
# __________________________________________________________________________________________________
# output00 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output01 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output02 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output03 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output04 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output05 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output06 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output07 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output08 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output09 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output10 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output11 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output12 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output13 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output14 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output15 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output16 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output17 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output18 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output19 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output20 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output21 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output22 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output23 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output24 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output25 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output26 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output27 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output28 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output29 (Dense)                (None, 1)            3           Dropout00[0][0]
# ==================================================================================================
# Total params: 298
# Trainable params: 298
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
#
# 12:46:34 Xval MSE 33.232254
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
#
# 12:49:40 Xval MSE 50.382995
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
#
# 12:53:41 Xval MSE 55.605630
# 12:53:41 Avg Xval loss 46.406960
# --------------------------------------------------------------------------------
# 12:53:41 Saving FFNN_46.406960_1_2_0.000100_0.250.h5
# 12:53:51 Running experiment 3 of 36
# 12:53:51 Generate splits [140, 280, 419, 558, 697]
# 12:53:51 Starting training
# layer 1 size 2, reg_penalty 0.00100000, dropout 0.250
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 103)          0
# __________________________________________________________________________________________________
# Dense00 (Dense)                 (None, 2)            208         main_input[0][0]
# __________________________________________________________________________________________________
# Dropout00 (Dropout)             (None, 2)            0           Dense00[0][0]
# __________________________________________________________________________________________________
# output00 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output01 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output02 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output03 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output04 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output05 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output06 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output07 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output08 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output09 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output10 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output11 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output12 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output13 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output14 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output15 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output16 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output17 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output18 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output19 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output20 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output21 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output22 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output23 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output24 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output25 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output26 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output27 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output28 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output29 (Dense)                (None, 1)            3           Dropout00[0][0]
# ==================================================================================================
# Total params: 298
# Trainable params: 298
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
#
# 12:55:59 Xval MSE 32.028255
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
#
# 12:59:06 Xval MSE 50.799714
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
#
# 13:03:06 Xval MSE 48.403688
# 13:03:06 Avg Xval loss 43.743886
# --------------------------------------------------------------------------------
# 13:03:06 Saving FFNN_43.743886_1_2_0.001000_0.250.h5
# 13:03:18 Running experiment 4 of 36
# 13:03:18 Generate splits [140, 280, 419, 558, 697]
# 13:03:18 Starting training
# layer 1 size 2, reg_penalty 0.01000000, dropout 0.250
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 103)          0
# __________________________________________________________________________________________________
# Dense00 (Dense)                 (None, 2)            208         main_input[0][0]
# __________________________________________________________________________________________________
# Dropout00 (Dropout)             (None, 2)            0           Dense00[0][0]
# __________________________________________________________________________________________________
# output00 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output01 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output02 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output03 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output04 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output05 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output06 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output07 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output08 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output09 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output10 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output11 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output12 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output13 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output14 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output15 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output16 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output17 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output18 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output19 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output20 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output21 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output22 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output23 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output24 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output25 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output26 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output27 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output28 (Dense)                (None, 1)            3           Dropout00[0][0]
# __________________________________________________________________________________________________
# output29 (Dense)                (None, 1)            3           Dropout00[0][0]
# ==================================================================================================
# Total params: 298
# Trainable params: 298
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
#
# 13:05:25 Xval MSE 32.391527
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
#
# 13:08:31 Xval MSE 58.442952
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
#
# 13:12:31 Xval MSE 43.553308
# 13:12:31 Avg Xval loss 44.795929
# --------------------------------------------------------------------------------
# 13:12:31 Saving FFNN_44.795929_1_2_0.010000_0.250.h5
# 13:12:43 Running experiment 5 of 36
# 13:12:43 Generate splits [140, 280, 419, 558, 697]
# 13:12:43 Starting training
# layer 1 size 4, reg_penalty 0.00000000, dropout 0.250
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 103)          0
# __________________________________________________________________________________________________
# Dense00 (Dense)                 (None, 4)            416         main_input[0][0]
# __________________________________________________________________________________________________
# Dropout00 (Dropout)             (None, 4)            0           Dense00[0][0]
# __________________________________________________________________________________________________
# output00 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output01 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output02 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output03 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output04 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output05 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output06 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output07 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output08 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output09 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output10 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output11 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output12 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output13 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output14 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output15 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output16 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output17 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output18 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output19 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output20 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output21 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output22 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output23 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output24 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output25 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output26 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output27 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output28 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output29 (Dense)                (None, 1)            5           Dropout00[0][0]
# ==================================================================================================
# Total params: 566
# Trainable params: 566
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
#
# 13:14:51 Xval MSE 33.087851
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
#
# 13:17:58 Xval MSE 60.424820
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
#
# 13:21:58 Xval MSE 56.644683
# 13:21:58 Avg Xval loss 50.052452
# --------------------------------------------------------------------------------
# 13:21:58 Saving FFNN_50.052452_1_4_0.000000_0.250.h5
# 13:22:11 Running experiment 6 of 36
# 13:22:11 Generate splits [140, 280, 419, 558, 697]
# 13:22:11 Starting training
# layer 1 size 4, reg_penalty 0.00010000, dropout 0.250
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 103)          0
# __________________________________________________________________________________________________
# Dense00 (Dense)                 (None, 4)            416         main_input[0][0]
# __________________________________________________________________________________________________
# Dropout00 (Dropout)             (None, 4)            0           Dense00[0][0]
# __________________________________________________________________________________________________
# output00 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output01 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output02 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output03 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output04 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output05 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output06 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output07 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output08 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output09 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output10 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output11 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output12 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output13 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output14 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output15 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output16 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output17 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output18 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output19 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output20 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output21 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output22 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output23 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output24 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output25 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output26 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output27 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output28 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output29 (Dense)                (None, 1)            5           Dropout00[0][0]
# ==================================================================================================
# Total params: 566
# Trainable params: 566
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
#
# 13:24:19 Xval MSE 34.863183
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
#
# 13:27:25 Xval MSE 66.336679
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
#
# 13:31:24 Xval MSE 52.730681
# 13:31:24 Avg Xval loss 51.310181
# --------------------------------------------------------------------------------
# 13:31:24 Saving FFNN_51.310181_1_4_0.000100_0.250.h5
# 13:31:38 Running experiment 7 of 36
# 13:31:38 Generate splits [140, 280, 419, 558, 697]
# 13:31:38 Starting training
# layer 1 size 4, reg_penalty 0.00100000, dropout 0.250
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 103)          0
# __________________________________________________________________________________________________
# Dense00 (Dense)                 (None, 4)            416         main_input[0][0]
# __________________________________________________________________________________________________
# Dropout00 (Dropout)             (None, 4)            0           Dense00[0][0]
# __________________________________________________________________________________________________
# output00 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output01 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output02 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output03 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output04 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# output05 (Dense)                (None, 1)            5           Dropout00[0][0]
# __________________________________________________________________________________________________
# ...
# output14 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output15 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output16 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output17 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output18 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output19 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output20 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output21 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output22 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output23 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output24 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output25 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output26 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output27 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output28 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output29 (Dense)                (None, 1)            9           Dropout00[0][0]
# ==================================================================================================
# Total params: 1,102
# Trainable params: 1,102
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
#
# 13:52:53 Xval MSE 33.855554
# Training indexes 0 to 418
# Cross-validating indexes 419 to 557
#
# 13:55:59 Xval MSE 76.415505
# Training indexes 0 to 557
# Cross-validating indexes 558 to 696
#
# 13:59:58 Xval MSE 63.290566
# 13:59:58 Avg Xval loss 57.853875
# --------------------------------------------------------------------------------
# 13:59:58 Saving FFNN_57.853875_1_8_0.000000_0.250.h5
# 14:00:13 Running experiment 10 of 36
# 14:00:13 Generate splits [140, 280, 419, 558, 697]
# 14:00:13 Starting training
# layer 1 size 8, reg_penalty 0.00010000, dropout 0.250
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 103)          0
# __________________________________________________________________________________________________
# Dense00 (Dense)                 (None, 8)            832         main_input[0][0]
# __________________________________________________________________________________________________
# Dropout00 (Dropout)             (None, 8)            0           Dense00[0][0]
# __________________________________________________________________________________________________
# output00 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output01 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output02 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output03 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output04 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output05 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output06 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output07 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output08 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output09 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output10 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output11 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output12 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output13 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output14 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output15 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output16 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output17 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output18 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output19 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output20 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output21 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output22 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output23 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output24 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output25 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output26 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output27 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output28 (Dense)                (None, 1)            9           Dropout00[0][0]
# __________________________________________________________________________________________________
# output29 (Dense)                (None, 1)            9           Dropout00[0][0]
# ==================================================================================================
# Total params: 1,102
# Trainable params: 1,102
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training indexes 0 to 279
# Cross-validating indexes 280 to 418
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-72-6c058108e5cc> in <module>()
#      25                                   reg_penalty = reg_penalty,
#      26                                   dropout = dropout,
# ---> 27                                   epochs=EPOCHS
#      28                                  )
#      29     experiments[key] = score
#
# <ipython-input-65-d9b6036d72b0> in run_experiment(X, Y, n_hidden_layers, layer_size, reg_penalty, dropout, minmaxscale, standardscale, epochs)
#      31                                                      reg_penalty=reg_penalty,
#      32                                                      dropout=dropout),
# ---> 33                                   epochs=epochs)
#
# <ipython-input-58-5c3960228b09> in walkforward_xval_keras(X, Y, create_model, n_splits, epochs)
#      38         Y_xval = Y[last_train_index:last_xval_index]
#      39
# ---> 40         fit = model.fit(X_fit, Y_fit, epochs=epochs)
#      41         # evaluate ... run prediction, calc MSE by industry, and average
#      42         Y_xval_pred = model.predict(X_xval)
#
# <ipython-input-71-3ade5c2ec1ab> in fit(self, X, Y, epochs)
#      58                               batch_size=BATCH_SIZE,
#      59                               epochs=epochs,
# ---> 60                               verbose=False)
#      61
#      62     def predict(self, X):
#
# /home/ubuntu/anaconda2/envs/tensorflow/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1655                               initial_epoch=initial_epoch,
#    1656                               steps_per_epoch=steps_per_epoch,
# -> 1657                               validation_steps=validation_steps)
#    1658
#    1659     def evaluate(self, x=None, y=None,
#
# /home/ubuntu/anaconda2/envs/tensorflow/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# /home/ubuntu/anaconda2/envs/tensorflow/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# /home/ubuntu/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ubuntu/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /home/ubuntu/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/ubuntu/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /home/ubuntu/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# list and chart experiments
flatlist = [list(l[0]) + [l[1]] for l in experiments.items()]

lossframe = pd.DataFrame(flatlist, columns=["n_hidden_layers", "layer_size", "reg_penalty", "dropout",
                                            "loss"])
lossframe.sort_values(['loss'])
# better than LinearRegression or MLPRegressor

# %%
# we can pick lowest loss , but first we look at patterns by hyperparameter
pd.DataFrame(lossframe.groupby(['n_hidden_layers'])['loss'].mean())

# %%
pd.DataFrame(lossframe.groupby(['layer_size'])['loss'].mean())

# %%
pd.DataFrame(lossframe.groupby(['reg_penalty'])['loss'].mean())

# %%
plot_matrix(lossframe, "n_hidden_layers", "layer_size", x_suffix=" units", y_suffix=" layers")

# %%
plot_matrix(lossframe, "n_hidden_layers", "reg_penalty", x_suffix="p", y_suffix=" layers")

# %%
plot_matrix(lossframe, "reg_penalty", "layer_size", x_suffix=" units", y_suffix="p")

# %%
EPOCHS=500

nrows = X.shape[0]
startindex = 1000

def run_backtest_keras(X, Y, arg_dict, startindex=0, epochs=EPOCHS, step=1, minmaxscale=False, standardscale=False):
    """create keras model; add step, to iteratively train, predict 12 months, train up to next 12 months """
    global P
    global R 
    
    print("%s Starting backtest" % (time.strftime("%H:%M:%S")))
    P = np.zeros((Y.shape[0],OUTPUT_DIM))
    
    count = 0
    nrows = X.shape[0]

    Xscale = X.copy()
    Yscale = Y.copy()
    
    if minmaxscale:
        # minmaxscale each row (min->0, max->1) - transpose, scale, transpose back because scales by columns
        Xscale = MinMaxScaler().fit_transform(Xscale.transpose()).transpose()
        Yscale = MinMaxScaler().fit_transform(Yscale.transpose()).transpose()
        print("using MinMaxScaler")
    elif standardscale:
        # standardize each row (mean->0, SD->1)- transpose, scale, transpose back because scales by columns
        Xscale = StandardScaler().fit_transform(Xscale.transpose()).transpose()
        Yscale = StandardScaler().fit_transform(Yscale.transpose()).transpose()
        print("using StandardScaler")
     
    model = create_keras_model(n_hidden_layers=arg_dict["n_hidden_layers"],
                               layer_size=arg_dict["hidden_layer_size"],
                               reg_penalty=arg_dict["reg_penalty"],
                               dropout=dropout,
                               verbose=False)()
        
    for train_index in range(startindex, nrows, step):
        if train_index + step >= nrows:
            train_index = nrows-step
            
        fp_index = train_index + step # eg 1000 + 26 = 1026

        # fit on e.g. 0:999, predict 1000-1025
        predictions = fit_predict_keras(Xscale[:fp_index, :], 
                                        Yscale[:fp_index], 
                                        model,
                                        epochs=epochs,
                                        npredict=step)
        # store in 1000:1025 - lining up with future Xs
        for i in range(step):
            P[train_index + i]= predictions[i]
            sys.stdout.write('.')
            count += 1
            if count % 80 == 0:
                print("")
                print("%s Still training %d of %d" % (time.strftime("%H:%M:%S"), count, nrows-startindex))
            sys.stdout.flush()

    msetemp = (P[startindex:]-Yscale[startindex:])**2
    #remove nans
    msetemp = msetemp[~np.isnan(msetemp)]
    mse = np.mean(msetemp)
    
    print("MSE across all predictions: %.4f" % mse)

# %%
def gen_returns(Y, P, first_pred_month, start_date='01/01/1970', freq='M', verbose=False):
    #TODO: more general version
    #take an indicator (P), a function to generate portfolio based on indicator, universe returns (Y), return portfolio returns

    global R
    R = np.zeros(P.shape[0])
    nrows, ncols = P.shape
    numstocks = 6 # top quintile (and bottom)

    indcount = [0 for response in responses]
    longcount = [0 for response in responses]
    shortcount = [0 for response in responses]
        
    for month_index in range(first_pred_month, nrows):
        # get indexes of sorted smallest to largest
        # leftmost 6
        # ignore nan
        short_sort_array = [999999 if np.isnan(x) else x for x in P[month_index]]
        select_array = np.argsort(short_sort_array)
        short_indexes = select_array[:numstocks]
        # rightmost 6
        long_sort_array = [-999999 if np.isnan(x) else x for x in P[month_index]]
        select_array = np.argsort(long_sort_array)
        long_indexes = select_array[-numstocks:]
        # compute equal weighted long/short return
        return_month = month_index + 1
        if verbose:
            print("Longs for month %d: %s" %(return_month, str([(l,P[month_index, l]) for l in long_indexes])))
            print("Shorts for month %d: %s" %(return_month, str([(l,P[month_index, l]) for l in short_indexes])))
            
        if return_month < nrows: # last row has a prediction for following month but no following month
            R[return_month] = np.mean(X[return_month, long_indexes])/2 - np.mean(X[return_month, short_indexes])/2
            # count occurrences of each industry
            for i in short_indexes:
                indcount[i]+=1
                shortcount[i]+=1
            for i in long_indexes:
                indcount[i]+=1
                longcount[i]+=1

    for response in responses:
        i = response_reverse_dict[response]
        print("%s: long %d times, short %d times, total %d times" % (response, longcount[i], shortcount[i], indcount[i]))
        
    results = R[first_pred_month:]

    index = pd.date_range(start_date,periods=results.shape[0], freq=freq)
    perfdata = pd.DataFrame(results,index=index,columns=['Returns'])
    perfdata['Equity'] = 100 * np.cumprod(1 + results / 100)

    stats = perfdata['Equity'].calc_stats()

    retframe = pd.DataFrame([stats.stats.loc['start'],
                             stats.stats.loc['end'],
                             stats.stats.loc['cagr'],
                             stats.stats.loc['yearly_vol'],
                             stats.stats.loc['yearly_sharpe'],
                             stats.stats.loc['max_drawdown'],
                             ffn.core.calc_sortino_ratio(perfdata.Returns, rf=0, nperiods=564, annualize=False),
                            ],
                            index = ['start',
                                     'end',
                                     'cagr',
                                     'yearly_vol',
                                     'yearly_sharpe',
                                     'max_drawdown',
                                     'sortino',
                                    ],
                            columns=['Value'])   
    return retframe

# %%
START=121
EPOCHS=500
STEP=5
arg_dict = {"n_hidden_layers" : 3,
            "hidden_layer_size" : 4,
            "reg_penalty" : 0.001,
            "dropout": 0.25,
            'verbose' : False
           }
     
#model = build_model(**arg_dict)
run_backtest_keras(X, Y, arg_dict, startindex=START, step=STEP, epochs=EPOCHS)
# Out:
# 14:15:04 Starting backtest
# ................................................................................
# 15:04:51 Still training 80 of 576
# ................................................................................
# 16:17:14 Still training 160 of 576
# ................................................................................
# 17:52:25 Still training 240 of 576
# ................................................................................
# 19:50:25 Still training 320 of 576
# ................................................................................
# 22:11:12 Still training 400 of 576
# ................................................................................
# 00:54:26 Still training 480 of 576
# ................................................................................
# 04:00:19 Still training 560 of 576
# ....................MSE across all predictions: 51.6907

# %%
gen_returns(X, P, FIRST_PREDICT_MONTH, verbose=False)
# Out:
# Food.lead: long 192 times, short 67 times, total 259 times
# Beer.lead: long 52 times, short 63 times, total 115 times
# Smoke.lead: long 234 times, short 88 times, total 322 times
# Games.lead: long 328 times, short 196 times, total 524 times
# Books.lead: long 60 times, short 8 times, total 68 times
# Hshld.lead: long 46 times, short 31 times, total 77 times
# Clths.lead: long 92 times, short 35 times, total 127 times
# Hlth.lead: long 84 times, short 45 times, total 129 times
# Chems.lead: long 0 times, short 254 times, total 254 times
# Txtls.lead: long 79 times, short 20 times, total 99 times
# Cnstr.lead: long 0 times, short 115 times, total 115 times
# Steel.lead: long 0 times, short 328 times, total 328 times
# FabPr.lead: long 1 times, short 19 times, total 20 times
# ElcEq.lead: long 122 times, short 4 times, total 126 times
# Autos.lead: long 0 times, short 97 times, total 97 times
# Carry.lead: long 226 times, short 70 times, total 296 times
# Mines.lead: long 119 times, short 129 times, total 248 times
# Coal.lead: long 255 times, short 41 times, total 296 times
# Oil.lead: long 224 times, short 288 times, total 512 times
# Util.lead: long 190 times, short 345 times, total 535 times
# Telcm.lead: long 195 times, short 344 times, total 539 times
# Servs.lead: long 319 times, short 175 times, total 494 times
# BusEq.lead: long 12 times, short 15 times, total 27 times
# Paper.lead: long 0 times, short 101 times, total 101 times
# Trans.lead: long 0 times, short 104 times, total 104 times
# Whlsl.lead: long 227 times, short 69 times, total 296 times
# Rtail.lead: long 7 times, short 4 times, total 11 times
# Meals.lead: long 343 times, short 182 times, total 525 times
# Fin.lead: long 1 times, short 0 times, total 1 times
# Other.lead: long 42 times, short 213 times, total 255 times
#                              Value
# start          1970-01-31 00:00:00
# end            2017-12-31 00:00:00
# cagr                    -0.0127782
# yearly_vol               0.0625832
# yearly_sharpe            -0.176748
# max_drawdown             -0.546734
# sortino                 -0.0815138
